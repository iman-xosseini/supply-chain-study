# %%
import pandas as pd

# %% [markdown]
# <br> <br>
#
# ## Overview

# %%
currency = pd.read_csv("../data/tradingeconomics/Overview/currency.csv", encoding="utf-16")

currency["Date"] = pd.to_datetime(currency["Date"], dayfirst=True, errors='coerce')

currency
# Out:
#           Symbol       Date     Open     High      Low   Close
# 0     USDBDT:CUR 2026-01-12  122.290  122.485  122.005  122.20
# 1     USDBDT:CUR 2026-01-09  122.200  122.200  122.200  122.20
# 2     USDBDT:CUR 2026-01-08  122.295  122.485  122.010  122.20
# 3     USDBDT:CUR 2026-01-07  122.285  122.475  122.010  122.20
# 4     USDBDT:CUR 2026-01-06  122.295  122.485  122.010  122.20
# ...          ...        ...      ...      ...      ...     ...
# 1330  USDBDT:CUR 2021-01-22   84.290   84.620   84.150   84.15
# 1331  USDBDT:CUR 2021-01-21   84.800   84.800   84.790   84.79
# 1332  USDBDT:CUR 2021-01-20   84.790   84.800   84.290   84.29
# 1333  USDBDT:CUR 2021-01-19   84.800   84.800   84.280   84.28
# 1334  USDBDT:CUR 2021-01-18   84.790   84.800   84.790   84.80
#
# [1335 rows x 6 columns]

# %%
stock_market = pd.read_csv("../data/tradingeconomics/Overview/stock_market.csv", encoding="utf-16")

stock_market["Date"] = pd.to_datetime(stock_market["Date"], dayfirst=True, errors='coerce')

stock_market
# Out:
#      Symbol       Date     Open     High      Low    Close
# 0  DSEX:IND 2026-01-12  4939.59  4950.07  4918.67  4942.05
# 1  DSEX:IND 2026-01-11  4998.55  5002.05  4939.59  4939.59
# 2  DSEX:IND 2026-01-08  4992.70  5011.96  4991.12  4998.55
# 3  DSEX:IND 2026-01-07  4953.61  5002.81  4953.61  4992.70
# 4  DSEX:IND 2026-01-06  4954.87  4983.67  4942.22  4953.61

# %%
annual_growth_rate = pd.read_csv("../data/tradingeconomics/Overview/annual_growth_rate.csv")

annual_growth_rate["DateTime"] = pd.to_datetime(annual_growth_rate["DateTime"], errors='coerce')

annual_growth_rate
# Out:
#       Country                Category   DateTime  Value Frequency  \
# 0  Bangladesh  GDP Annual Growth Rate 1994-06-30   4.08    Yearly
# 1  Bangladesh  GDP Annual Growth Rate 1995-06-30   4.93    Yearly
# 2  Bangladesh  GDP Annual Growth Rate 1996-06-30   4.62    Yearly
# 3  Bangladesh  GDP Annual Growth Rate 1997-06-30   5.39    Yearly
# 4  Bangladesh  GDP Annual Growth Rate 1998-06-30   5.23    Yearly
#
#   HistoricalDataSymbol           LastUpdate
# 0     BangladeshGDPYoY  2025-05-22T03:04:00
# 1     BangladeshGDPYoY  2025-05-22T03:04:00
# 2     BangladeshGDPYoY  2025-05-22T03:04:00
# 3     BangladeshGDPYoY  2025-05-22T03:04:00
# 4     BangladeshGDPYoY  2025-05-22T03:04:00

# %%
unemployment_rate = pd.read_csv("../data/tradingeconomics/Overview/unemployment_rate.csv")

unemployment_rate["DateTime"] = pd.to_datetime(unemployment_rate["DateTime"], errors='coerce')

unemployment_rate
# Out:
#       Country           Category   DateTime  Value Frequency  \
# 0  Bangladesh  Unemployment Rate 1991-12-31    2.2    Yearly
# 1  Bangladesh  Unemployment Rate 1992-12-31    2.3    Yearly
# 2  Bangladesh  Unemployment Rate 1993-12-31    2.3    Yearly
# 3  Bangladesh  Unemployment Rate 1994-12-31    2.4    Yearly
# 4  Bangladesh  Unemployment Rate 1995-12-31    2.4    Yearly
#
#   HistoricalDataSymbol           LastUpdate
# 0         BangladeshUR  2017-06-06T11:46:00
# 1         BangladeshUR  2024-02-06T02:39:00
# 2         BangladeshUR  2024-02-06T02:39:00
# 3         BangladeshUR  2024-02-06T02:39:00
# 4         BangladeshUR  2024-02-06T02:39:00

# %%
inflation_rate = pd.read_csv("../data/tradingeconomics/Overview/inflation_rate.csv")

inflation_rate["DateTime"] = pd.to_datetime(inflation_rate["DateTime"], errors='coerce')

inflation_rate
# Out:
#       Country        Category   DateTime  Value Frequency  \
# 0  Bangladesh  Inflation Rate 1994-07-31   5.50   Monthly
# 1  Bangladesh  Inflation Rate 1994-08-31   7.11   Monthly
# 2  Bangladesh  Inflation Rate 1994-09-30   6.84   Monthly
# 3  Bangladesh  Inflation Rate 1994-10-31   8.30   Monthly
# 4  Bangladesh  Inflation Rate 1994-11-30   7.62   Monthly
#
#   HistoricalDataSymbol           LastUpdate
# 0         BangladeshIR  2016-04-05T14:51:00
# 1         BangladeshIR  2016-04-05T14:51:00
# 2         BangladeshIR  2016-04-05T14:51:00
# 3         BangladeshIR  2016-04-05T14:51:00
# 4         BangladeshIR  2016-04-05T14:51:00

# %%
interest_rate = pd.read_csv("../data/tradingeconomics/Overview/interest_rate.csv")

interest_rate["DateTime"] = pd.to_datetime(interest_rate["DateTime"], errors='coerce')

interest_rate
# Out:
#       Country       Category   DateTime  Value Frequency HistoricalDataSymbol  \
# 0  Bangladesh  Interest Rate 2008-01-31    8.5     Daily    BangladeshIntRate
# 1  Bangladesh  Interest Rate 2008-02-29    8.5     Daily    BangladeshIntRate
# 2  Bangladesh  Interest Rate 2008-03-31    8.5     Daily    BangladeshIntRate
# 3  Bangladesh  Interest Rate 2008-04-30    8.5     Daily    BangladeshIntRate
# 4  Bangladesh  Interest Rate 2008-05-31    8.5     Daily    BangladeshIntRate
#
#             LastUpdate
# 0  2011-06-27T00:00:00
# 1  2011-06-27T00:00:00
# 2  2011-06-27T00:00:00
# 3  2011-06-27T00:00:00
# 4  2011-06-27T00:00:00

# %%
balance_of_trade = pd.read_csv("../data/tradingeconomics/Overview/balance_of_trade.csv")

balance_of_trade["DateTime"] = pd.to_datetime(balance_of_trade["DateTime"], errors='coerce')
balance_of_trade["LastUpdate"] = pd.to_datetime(balance_of_trade["LastUpdate"], errors='coerce')

balance_of_trade
# Out:
#       Country          Category   DateTime  Value Frequency  \
# 0  Bangladesh  Balance of Trade 1976-03-31   -1.2   Monthly
# 1  Bangladesh  Balance of Trade 1976-04-30   -0.6   Monthly
# 2  Bangladesh  Balance of Trade 1976-05-31   -0.6   Monthly
# 3  Bangladesh  Balance of Trade 1976-06-30   -1.4   Monthly
# 4  Bangladesh  Balance of Trade 1976-07-31   -0.7   Monthly
#
#   HistoricalDataSymbol          LastUpdate
# 0         BangladeshBT 2014-08-26 18:11:00
# 1         BangladeshBT 2014-08-26 18:11:00
# 2         BangladeshBT 2014-11-16 21:27:00
# 3         BangladeshBT 2014-08-26 18:11:00
# 4         BangladeshBT 2014-08-26 18:11:00

# %%
current_account = pd.read_csv("../data/tradingeconomics/Overview/current_account.csv")

current_account["DateTime"] = pd.to_datetime(current_account["DateTime"], errors='coerce')
current_account["LastUpdate"] = pd.to_datetime(current_account["LastUpdate"], errors='coerce')

current_account
# Out:
#       Country         Category   DateTime  Value Frequency  \
# 0  Bangladesh  Current Account 2005-06-30 -557.0   Monthly
# 1  Bangladesh  Current Account 2006-06-30  824.0   Monthly
# 2  Bangladesh  Current Account 2007-06-30  952.0   Monthly
# 3  Bangladesh  Current Account 2008-06-30  680.0   Monthly
# 4  Bangladesh  Current Account 2008-09-30  366.0   Monthly
#
#   HistoricalDataSymbol LastUpdate
# 0         BangladeshCA 2011-06-27
# 1         BangladeshCA 2011-06-27
# 2         BangladeshCA 2011-06-27
# 3         BangladeshCA 2011-06-27
# 4         BangladeshCA 2011-06-27

# %%
current_account_to_GDP = pd.read_csv("../data/tradingeconomics/Overview/current_account_to_GDP.csv")

current_account_to_GDP["DateTime"] = pd.to_datetime(current_account_to_GDP["DateTime"], errors='coerce')
current_account_to_GDP["LastUpdate"] = pd.to_datetime(current_account_to_GDP["LastUpdate"], errors='coerce')

current_account_to_GDP
# Out:
#       Country                Category   DateTime  Value Frequency  \
# 0  Bangladesh  Current Account to GDP 1980-12-31   -0.8    Yearly
# 1  Bangladesh  Current Account to GDP 1981-12-31   -1.8    Yearly
# 2  Bangladesh  Current Account to GDP 1982-12-31   -2.7    Yearly
# 3  Bangladesh  Current Account to GDP 1983-12-31   -2.2    Yearly
# 4  Bangladesh  Current Account to GDP 1984-12-31   -1.9    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0            BGDCA2GDP 2025-01-28 07:24:00
# 1            BGDCA2GDP 2025-01-28 07:24:00
# 2            BGDCA2GDP 2025-01-28 07:24:00
# 3            BGDCA2GDP 2025-01-28 07:24:00
# 4            BGDCA2GDP 2025-01-28 07:24:00

# %%
government_debt_to_GDP = pd.read_csv("../data/tradingeconomics/Overview/government_debt_to_GDP.csv")

government_debt_to_GDP["DateTime"] = pd.to_datetime(government_debt_to_GDP["DateTime"], errors='coerce')
government_debt_to_GDP["LastUpdate"] = pd.to_datetime(government_debt_to_GDP["LastUpdate"], errors='coerce')

government_debt_to_GDP
# Out:
#        Country                Category   DateTime  Value Frequency  \
# 0   Bangladesh  Government Debt to GDP 1995-12-31   49.0    Yearly
# 1   Bangladesh  Government Debt to GDP 1996-12-31   43.9    Yearly
# 2   Bangladesh  Government Debt to GDP 1997-12-31   43.2    Yearly
# 3   Bangladesh  Government Debt to GDP 1998-12-31   40.4    Yearly
# 4   Bangladesh  Government Debt to GDP 1999-12-31   42.4    Yearly
# 5   Bangladesh  Government Debt to GDP 2000-12-31   46.4    Yearly
# 6   Bangladesh  Government Debt to GDP 2001-12-31   46.2    Yearly
# 7   Bangladesh  Government Debt to GDP 2002-12-31   50.0    Yearly
# 8   Bangladesh  Government Debt to GDP 2003-12-31   49.0    Yearly
# 9   Bangladesh  Government Debt to GDP 2004-12-31   48.2    Yearly
# 10  Bangladesh  Government Debt to GDP 2005-12-31   46.9    Yearly
# 11  Bangladesh  Government Debt to GDP 2006-12-31   40.2    Yearly
# 12  Bangladesh  Government Debt to GDP 2007-12-31   38.6    Yearly
# ...

# %%
government_budget = pd.read_csv("../data/tradingeconomics/Overview/government_budget.csv")

government_budget["DateTime"] = pd.to_datetime(government_budget["DateTime"], errors='coerce')
government_budget["LastUpdate"] = pd.to_datetime(government_budget["LastUpdate"], errors='coerce')

government_budget
# Out:
#        Country           Category   DateTime  Value Frequency  \
# 0   Bangladesh  Government Budget 1991-12-31  -3.30    Yearly
# 1   Bangladesh  Government Budget 1992-12-31  -2.10    Yearly
# 2   Bangladesh  Government Budget 1993-12-31  -1.30    Yearly
# 3   Bangladesh  Government Budget 1994-12-31  -3.70    Yearly
# 4   Bangladesh  Government Budget 1995-12-31  -2.20    Yearly
# 5   Bangladesh  Government Budget 1996-12-31  -3.00    Yearly
# 6   Bangladesh  Government Budget 1997-12-31  -2.00    Yearly
# 7   Bangladesh  Government Budget 1998-12-31  -2.10    Yearly
# 8   Bangladesh  Government Budget 1999-12-31  -3.20    Yearly
# 9   Bangladesh  Government Budget 2000-12-31  -4.50    Yearly
# 10  Bangladesh  Government Budget 2001-12-31  -4.10    Yearly
# 11  Bangladesh  Government Budget 2002-12-31  -3.70    Yearly
# 12  Bangladesh  Government Budget 2003-12-31  -3.70    Yearly
# 13  Bangladesh  Government Budget 2004-12-31  -3.40    Yearly
# ...

# %%
corporate_tax_rate = pd.read_csv("../data/tradingeconomics/Overview/corporate_tax_rate.csv")

corporate_tax_rate["DateTime"] = pd.to_datetime(corporate_tax_rate["DateTime"], errors='coerce')
corporate_tax_rate["LastUpdate"] = pd.to_datetime(corporate_tax_rate["LastUpdate"], errors='coerce')

corporate_tax_rate
# Out:
#        Country            Category   DateTime  Value Frequency  \
# 0   Bangladesh  Corporate Tax Rate 1997-12-31   40.0    Yearly
# 1   Bangladesh  Corporate Tax Rate 1998-12-31   40.0    Yearly
# 2   Bangladesh  Corporate Tax Rate 1999-12-31   35.0    Yearly
# 3   Bangladesh  Corporate Tax Rate 2000-12-31   35.0    Yearly
# 4   Bangladesh  Corporate Tax Rate 2001-12-31   35.0    Yearly
# 5   Bangladesh  Corporate Tax Rate 2002-12-31   35.0    Yearly
# 6   Bangladesh  Corporate Tax Rate 2003-12-31   30.0    Yearly
# 7   Bangladesh  Corporate Tax Rate 2004-12-31   30.0    Yearly
# 8   Bangladesh  Corporate Tax Rate 2005-12-31   30.0    Yearly
# 9   Bangladesh  Corporate Tax Rate 2006-12-31   30.0    Yearly
# 10  Bangladesh  Corporate Tax Rate 2007-12-31   30.0    Yearly
# 11  Bangladesh  Corporate Tax Rate 2008-12-31   30.0    Yearly
# 12  Bangladesh  Corporate Tax Rate 2009-12-31   27.5    Yearly
# 13  Bangladesh  Corporate Tax Rate 2010-12-31   27.5    Yearly
# ...

# %%
personal_income_tax_rate = pd.read_csv("../data/tradingeconomics/Overview/personal_income_Tax_Rate.csv")

personal_income_tax_rate["DateTime"] = pd.to_datetime(personal_income_tax_rate["DateTime"], errors='coerce')
personal_income_tax_rate["LastUpdate"] = pd.to_datetime(personal_income_tax_rate["LastUpdate"], errors='coerce')

personal_income_tax_rate
# Out:
#        Country                  Category   DateTime  Value Frequency  \
# 0   Bangladesh  Personal Income Tax Rate 2004-12-31     25    Yearly
# 1   Bangladesh  Personal Income Tax Rate 2005-12-31     25    Yearly
# 2   Bangladesh  Personal Income Tax Rate 2006-12-31     25    Yearly
# 3   Bangladesh  Personal Income Tax Rate 2007-12-31     25    Yearly
# 4   Bangladesh  Personal Income Tax Rate 2008-12-31     25    Yearly
# 5   Bangladesh  Personal Income Tax Rate 2009-12-31     25    Yearly
# 6   Bangladesh  Personal Income Tax Rate 2010-12-31     25    Yearly
# 7   Bangladesh  Personal Income Tax Rate 2011-12-31     25    Yearly
# 8   Bangladesh  Personal Income Tax Rate 2012-12-31     25    Yearly
# 9   Bangladesh  Personal Income Tax Rate 2013-12-31     25    Yearly
# 10  Bangladesh  Personal Income Tax Rate 2014-12-31     30    Yearly
# 11  Bangladesh  Personal Income Tax Rate 2015-12-31     30    Yearly
# 12  Bangladesh  Personal Income Tax Rate 2016-12-31     30    Yearly
# ...

# %% [markdown]
# <br> <br>
#
# ## GDP

# %%
gdp_annual_growth_rate = pd.read_csv("../data/tradingeconomics/GDP/GDP_Annual_Growth_Rate.csv")

gdp_annual_growth_rate["DateTime"] = pd.to_datetime(gdp_annual_growth_rate["DateTime"], errors='coerce')
gdp_annual_growth_rate["LastUpdate"] = pd.to_datetime(gdp_annual_growth_rate["LastUpdate"], errors='coerce')

gdp_annual_growth_rate
# Out:
#        Country                Category   DateTime  Value Frequency  \
# 0   Bangladesh  GDP Annual Growth Rate 1994-06-30   4.08    Yearly
# 1   Bangladesh  GDP Annual Growth Rate 1995-06-30   4.93    Yearly
# 2   Bangladesh  GDP Annual Growth Rate 1996-06-30   4.62    Yearly
# 3   Bangladesh  GDP Annual Growth Rate 1997-06-30   5.39    Yearly
# 4   Bangladesh  GDP Annual Growth Rate 1998-06-30   5.23    Yearly
# 5   Bangladesh  GDP Annual Growth Rate 1999-06-30   4.87    Yearly
# 6   Bangladesh  GDP Annual Growth Rate 2000-06-30   5.94    Yearly
# 7   Bangladesh  GDP Annual Growth Rate 2001-06-30   5.27    Yearly
# 8   Bangladesh  GDP Annual Growth Rate 2002-06-30   4.42    Yearly
# 9   Bangladesh  GDP Annual Growth Rate 2003-06-30   5.26    Yearly
# 10  Bangladesh  GDP Annual Growth Rate 2004-06-30   6.27    Yearly
# 11  Bangladesh  GDP Annual Growth Rate 2005-06-30   5.96    Yearly
# 12  Bangladesh  GDP Annual Growth Rate 2006-06-30   6.63    Yearly
# ...

# %%
gdp = pd.read_csv("../data/tradingeconomics/GDP/GDP.csv")

gdp["DateTime"] = pd.to_datetime(gdp["DateTime"], errors='coerce')
gdp["LastUpdate"] = pd.to_datetime(gdp["LastUpdate"], errors='coerce')

gdp
# Out:
#        Country Category   DateTime   Value Frequency HistoricalDataSymbol  \
# 0   Bangladesh      GDP 1960-12-31    4.27    Yearly        BangladeshGDP
# 1   Bangladesh      GDP 1961-12-31    4.82    Yearly        BangladeshGDP
# 2   Bangladesh      GDP 1962-12-31    5.08    Yearly        BangladeshGDP
# 3   Bangladesh      GDP 1963-12-31    5.32    Yearly        BangladeshGDP
# 4   Bangladesh      GDP 1964-12-31    5.39    Yearly        BangladeshGDP
# ..         ...      ...        ...     ...       ...                  ...
# 60  Bangladesh      GDP 2020-12-31  373.98    Yearly        BangladeshGDP
# 61  Bangladesh      GDP 2021-12-31  416.27    Yearly        BangladeshGDP
# 62  Bangladesh      GDP 2022-12-31  460.13    Yearly        BangladeshGDP
# 63  Bangladesh      GDP 2023-12-31  437.42    Yearly        BangladeshGDP
# 64  Bangladesh      GDP 2024-12-31  450.12    Yearly        BangladeshGDP
#
#             LastUpdate
# 0  2019-07-01 15:48:00
# 1  2019-07-01 15:48:00
# ...

# %%
gdp_constant_prices = pd.read_csv("../data/tradingeconomics/GDP/GDP_Constant_Prices.csv")

gdp_constant_prices["DateTime"] = pd.to_datetime(gdp_constant_prices["DateTime"], errors='coerce')
gdp_constant_prices["LastUpdate"] = pd.to_datetime(gdp_constant_prices["LastUpdate"], errors='coerce')

gdp_constant_prices
# Out:
#       Country             Category   DateTime    Value Frequency  \
# 0  Bangladesh  GDP Constant Prices 2016-06-30  20758.2    Yearly
# 1  Bangladesh  GDP Constant Prices 2017-06-30  22126.2    Yearly
# 2  Bangladesh  GDP Constant Prices 2018-06-30  23745.7    Yearly
# 3  Bangladesh  GDP Constant Prices 2019-06-30  25617.4    Yearly
# 4  Bangladesh  GDP Constant Prices 2020-06-30  26500.6    Yearly
# 5  Bangladesh  GDP Constant Prices 2021-06-30  28339.4    Yearly
# 6  Bangladesh  GDP Constant Prices 2022-06-30  30351.5    Yearly
# 7  Bangladesh  GDP Constant Prices 2023-06-30  32104.3    Yearly
# 8  Bangladesh  GDP Constant Prices 2024-06-30  33460.2    Yearly
# 9  Bangladesh  GDP Constant Prices 2025-06-30  34790.0    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0  BANGLADESHGDPCONPRI 2025-05-22 02:55:00
# 1  BANGLADESHGDPCONPRI 2025-05-22 02:55:00
# 2  BANGLADESHGDPCONPRI 2025-05-22 02:55:00
# 3  BANGLADESHGDPCONPRI 2025-05-22 02:55:00
# ...

# %%
gross_national_product = pd.read_csv("../data/tradingeconomics/GDP/Gross_National_Product.csv")

gross_national_product["DateTime"] = pd.to_datetime(gross_national_product["DateTime"], errors='coerce')
gross_national_product["LastUpdate"] = pd.to_datetime(gross_national_product["LastUpdate"], errors='coerce')

gross_national_product
# Out:
#       Country                Category   DateTime    Value Frequency  \
# 0  Bangladesh  Gross National Product 2016-06-30  21730.8    Yearly
# 1  Bangladesh  Gross National Product 2017-06-30  22890.2    Yearly
# 2  Bangladesh  Gross National Product 2018-06-30  24695.3    Yearly
# 3  Bangladesh  Gross National Product 2019-06-30  26666.7    Yearly
# 4  Bangladesh  Gross National Product 2020-06-30  27597.6    Yearly
# 5  Bangladesh  Gross National Product 2021-06-30  29831.1    Yearly
# 6  Bangladesh  Gross National Product 2022-06-30  31553.9    Yearly
# 7  Bangladesh  Gross National Product 2023-06-30  33385.7    Yearly
# 8  Bangladesh  Gross National Product 2024-06-30  34901.1    Yearly
# 9  Bangladesh  Gross National Product 2025-06-30  36734.6    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0  BANGLADESHGRONATPRO 2025-05-22 05:35:00
# 1  BANGLADESHGRONATPRO 2025-05-22 05:35:00
# 2  BANGLADESHGRONATPRO 2025-05-22 05:35:00
# 3  BANGLADESHGRONATPRO 2025-05-22 05:35:00
# ...

# %%
gross_fixed_capital_formation = pd.read_csv("../data/tradingeconomics/GDP/Gross_Fixed_Capital_Formation.csv")

gross_fixed_capital_formation["DateTime"] = pd.to_datetime(gross_fixed_capital_formation["DateTime"], errors='coerce')
gross_fixed_capital_formation["LastUpdate"] = pd.to_datetime(gross_fixed_capital_formation["LastUpdate"], errors='coerce')

gross_fixed_capital_formation
# Out:
#       Country                       Category   DateTime    Value Frequency  \
# 0  Bangladesh  Gross Fixed Capital Formation 2016-06-30   6277.2    Yearly
# 1  Bangladesh  Gross Fixed Capital Formation 2017-06-30   6802.0    Yearly
# 2  Bangladesh  Gross Fixed Capital Formation 2018-06-30   7627.3    Yearly
# 3  Bangladesh  Gross Fixed Capital Formation 2019-06-30   8152.0    Yearly
# 4  Bangladesh  Gross Fixed Capital Formation 2020-06-30   8473.7    Yearly
# 5  Bangladesh  Gross Fixed Capital Formation 2021-06-30   9159.3    Yearly
# 6  Bangladesh  Gross Fixed Capital Formation 2022-06-30  10226.7    Yearly
# 7  Bangladesh  Gross Fixed Capital Formation 2023-06-30  10452.8    Yearly
# 8  Bangladesh  Gross Fixed Capital Formation 2024-06-30  10794.2    Yearly
# 9  Bangladesh  Gross Fixed Capital Formation 2025-06-30  10984.5    Yearly
#
#    HistoricalDataSymbol          LastUpdate
# 0  BANGLADESHGROFIXCAPF 2025-05-22 03:30:00
# 1  BANGLADESHGROFIXCAPF 2025-05-22 03:30:00
# ...

# %%
gdp_per_capita = pd.read_csv("../data/tradingeconomics/GDP/GDP_per_Capita.csv")

gdp_per_capita["DateTime"] = pd.to_datetime(gdp_per_capita["DateTime"], errors='coerce')
gdp_per_capita["LastUpdate"] = pd.to_datetime(gdp_per_capita["LastUpdate"], errors='coerce')

gdp_per_capita
# Out:
#        Country        Category   DateTime    Value Frequency  \
# 0   Bangladesh  GDP per Capita 1960-12-31   429.40    Yearly
# 1   Bangladesh  GDP per Capita 1961-12-31   442.75    Yearly
# 2   Bangladesh  GDP per Capita 1962-12-31   453.53    Yearly
# 3   Bangladesh  GDP per Capita 1963-12-31   438.50    Yearly
# 4   Bangladesh  GDP per Capita 1964-12-31   472.53    Yearly
# ..         ...             ...        ...      ...       ...
# 60  Bangladesh  GDP per Capita 2020-12-31  1604.67    Yearly
# 61  Bangladesh  GDP per Capita 2021-12-31  1702.08    Yearly
# 62  Bangladesh  GDP per Capita 2022-12-31  1804.35    Yearly
# 63  Bangladesh  GDP per Capita 2023-12-31  1885.38    Yearly
# 64  Bangladesh  GDP per Capita 2024-12-31  1941.28    Yearly
#
#    HistoricalDataSymbol          LastUpdate
# 0        BGDNYGDPPCAPKD 2025-02-21 07:39:00
# 1        BGDNYGDPPCAPKD 2025-02-21 07:39:00
# 2        BGDNYGDPPCAPKD 2025-02-21 07:39:00
# 3        BGDNYGDPPCAPKD 2025-02-21 07:39:00
# ...

# %%
gdp_per_capita_ppp = pd.read_csv("../data/tradingeconomics/GDP/GDP_per_Capita_PPP.csv")

gdp_per_capita_ppp["DateTime"] = pd.to_datetime(gdp_per_capita_ppp["DateTime"], errors='coerce')
gdp_per_capita_ppp["LastUpdate"] = pd.to_datetime(gdp_per_capita_ppp["LastUpdate"], errors='coerce')

gdp_per_capita_ppp
# Out:
#        Country            Category   DateTime    Value Frequency  \
# 0   Bangladesh  GDP per Capita PPP 1990-12-31  2069.78    Yearly
# 1   Bangladesh  GDP per Capita PPP 1991-12-31  2101.38    Yearly
# 2   Bangladesh  GDP per Capita PPP 1992-12-31  2174.38    Yearly
# 3   Bangladesh  GDP per Capita PPP 1993-12-31  2234.81    Yearly
# 4   Bangladesh  GDP per Capita PPP 1994-12-31  2279.09    Yearly
# 5   Bangladesh  GDP per Capita PPP 1995-12-31  2351.70    Yearly
# 6   Bangladesh  GDP per Capita PPP 1996-12-31  2413.54    Yearly
# 7   Bangladesh  GDP per Capita PPP 1997-12-31  2475.60    Yearly
# 8   Bangladesh  GDP per Capita PPP 1998-12-31  2555.06    Yearly
# 9   Bangladesh  GDP per Capita PPP 1999-12-31  2624.07    Yearly
# 10  Bangladesh  GDP per Capita PPP 2000-12-31  2712.94    Yearly
# 11  Bangladesh  GDP per Capita PPP 2001-12-31  2803.55    Yearly
# 12  Bangladesh  GDP per Capita PPP 2002-12-31  2866.43    Yearly
# ...

# %%
gdp_from_agriculture = pd.read_csv("../data/tradingeconomics/GDP/GDP_from_Agriculture.csv")

gdp_from_agriculture["DateTime"] = pd.to_datetime(gdp_from_agriculture["DateTime"], errors='coerce')
gdp_from_agriculture["LastUpdate"] = pd.to_datetime(gdp_from_agriculture["LastUpdate"], errors='coerce')

gdp_from_agriculture
# Out:
#       Country              Category   DateTime   Value Frequency  \
# 0  Bangladesh  GDP from Agriculture 2016-06-30  2795.1    Yearly
# 1  Bangladesh  GDP from Agriculture 2017-06-30  2884.4    Yearly
# 2  Bangladesh  GDP from Agriculture 2018-06-30  2986.6    Yearly
# 3  Bangladesh  GDP from Agriculture 2019-06-30  3084.0    Yearly
# 4  Bangladesh  GDP from Agriculture 2020-06-30  3189.5    Yearly
# 5  Bangladesh  GDP from Agriculture 2021-06-30  3290.8    Yearly
# 6  Bangladesh  GDP from Agriculture 2022-06-30  3391.3    Yearly
# 7  Bangladesh  GDP from Agriculture 2023-06-30  3505.6    Yearly
# 8  Bangladesh  GDP from Agriculture 2024-06-30  3621.4    Yearly
# 9  Bangladesh  GDP from Agriculture 2025-06-30  3686.3    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0  BANGLADESHGDPFROAGR 2025-05-22 03:03:00
# 1  BANGLADESHGDPFROAGR 2025-05-22 03:03:00
# 2  BANGLADESHGDPFROAGR 2025-05-22 03:03:00
# 3  BANGLADESHGDPFROAGR 2025-05-22 03:03:00
# ...

# %%
gdp_from_construction = pd.read_csv("../data/tradingeconomics/GDP/GDP_from_Construction.csv")

gdp_from_construction["DateTime"] = pd.to_datetime(gdp_from_construction["DateTime"], errors='coerce')
gdp_from_construction["LastUpdate"] = pd.to_datetime(gdp_from_construction["LastUpdate"], errors='coerce')

gdp_from_construction
# Out:
#       Country               Category   DateTime   Value Frequency  \
# 0  Bangladesh  GDP from Construction 2016-06-30  1628.4    Yearly
# 1  Bangladesh  GDP from Construction 2017-06-30  1787.3    Yearly
# 2  Bangladesh  GDP from Construction 2018-06-30  1967.1    Yearly
# 3  Bangladesh  GDP from Construction 2019-06-30  2173.1    Yearly
# 4  Bangladesh  GDP from Construction 2020-06-30  2371.5    Yearly
# 5  Bangladesh  GDP from Construction 2021-06-30  2563.0    Yearly
# 6  Bangladesh  GDP from Construction 2022-06-30  2786.3    Yearly
# 7  Bangladesh  GDP from Construction 2023-06-30  2980.8    Yearly
# 8  Bangladesh  GDP from Construction 2024-06-30  3148.5    Yearly
# 9  Bangladesh  GDP from Construction 2025-06-30  3194.3    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0  BANGLADESHGDPFROCON 2025-05-22 03:09:00
# 1  BANGLADESHGDPFROCON 2025-05-22 03:09:00
# 2  BANGLADESHGDPFROCON 2025-05-22 03:09:00
# 3  BANGLADESHGDPFROCON 2025-05-22 03:09:00
# ...

# %%
gdp_from_manufacturing = pd.read_csv("../data/tradingeconomics/GDP/GDP_from_Manufacturing.csv")

gdp_from_manufacturing["DateTime"] = pd.to_datetime(gdp_from_manufacturing["DateTime"], errors='coerce')
gdp_from_manufacturing["LastUpdate"] = pd.to_datetime(gdp_from_manufacturing["LastUpdate"], errors='coerce')

gdp_from_manufacturing
# Out:
#       Country                Category   DateTime   Value Frequency  \
# 0  Bangladesh  GDP from Manufacturing 2016-06-30  4223.9    Yearly
# 1  Bangladesh  GDP from Manufacturing 2017-06-30  4523.2    Yearly
# 2  Bangladesh  GDP from Manufacturing 2018-06-30  4996.0    Yearly
# 3  Bangladesh  GDP from Manufacturing 2019-06-30  5612.2    Yearly
# 4  Bangladesh  GDP from Manufacturing 2020-06-30  5706.5    Yearly
# 5  Bangladesh  GDP from Manufacturing 2021-06-30  6367.6    Yearly
# 6  Bangladesh  GDP from Manufacturing 2022-06-30  7094.2    Yearly
# 7  Bangladesh  GDP from Manufacturing 2023-06-30  7725.2    Yearly
# 8  Bangladesh  GDP from Manufacturing 2024-06-30  7969.1    Yearly
# 9  Bangladesh  GDP from Manufacturing 2025-06-30  8421.9    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0  BANGLADESHGDPFROMAN 2025-05-22 03:12:00
# 1  BANGLADESHGDPFROMAN 2025-05-22 03:12:00
# 2  BANGLADESHGDPFROMAN 2025-05-22 03:12:00
# 3  BANGLADESHGDPFROMAN 2025-05-22 03:12:00
# ...

# %%
gdp_from_mining = pd.read_csv("../data/tradingeconomics/GDP/GDP_from_Mining.csv")

gdp_from_mining["DateTime"] = pd.to_datetime(gdp_from_mining["DateTime"], errors='coerce')
gdp_from_mining["LastUpdate"] = pd.to_datetime(gdp_from_mining["LastUpdate"], errors='coerce')

gdp_from_mining
# Out:
#       Country         Category   DateTime  Value Frequency  \
# 0  Bangladesh  GDP from Mining 2016-06-30  330.5    Yearly
# 1  Bangladesh  GDP from Mining 2017-06-30  387.7    Yearly
# 2  Bangladesh  GDP from Mining 2018-06-30  424.7    Yearly
# 3  Bangladesh  GDP from Mining 2019-06-30  472.7    Yearly
# 4  Bangladesh  GDP from Mining 2020-06-30  487.7    Yearly
# 5  Bangladesh  GDP from Mining 2021-06-30  519.3    Yearly
# 6  Bangladesh  GDP from Mining 2022-06-30  513.5    Yearly
# 7  Bangladesh  GDP from Mining 2023-06-30  578.9    Yearly
# 8  Bangladesh  GDP from Mining 2024-06-30  572.2    Yearly
# 9  Bangladesh  GDP from Mining 2025-06-30  578.2    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0  BANGLADESHGDPFROMIN 2025-05-22 03:14:00
# 1  BANGLADESHGDPFROMIN 2025-05-22 03:14:00
# 2  BANGLADESHGDPFROMIN 2025-05-22 03:14:00
# 3  BANGLADESHGDPFROMIN 2025-05-22 03:14:00
# 4  BANGLADESHGDPFROMIN 2025-05-22 03:14:00
# 5  BANGLADESHGDPFROMIN 2025-05-22 03:14:00
# ...

# %%
gdp_from_public_administration = pd.read_csv("../data/tradingeconomics/GDP/GDP_from_Public_Administration.csv")

gdp_from_public_administration["DateTime"] = pd.to_datetime(gdp_from_public_administration["DateTime"], errors='coerce')
gdp_from_public_administration["LastUpdate"] = pd.to_datetime(gdp_from_public_administration["LastUpdate"], errors='coerce')

gdp_from_public_administration
# Out:
#       Country                        Category   DateTime   Value Frequency  \
# 0  Bangladesh  GDP from Public Administration 2016-06-30   667.3    Yearly
# 1  Bangladesh  GDP from Public Administration 2017-06-30   742.2    Yearly
# 2  Bangladesh  GDP from Public Administration 2018-06-30   806.6    Yearly
# 3  Bangladesh  GDP from Public Administration 2019-06-30   858.9    Yearly
# 4  Bangladesh  GDP from Public Administration 2020-06-30   906.0    Yearly
# 5  Bangladesh  GDP from Public Administration 2021-06-30   960.8    Yearly
# 6  Bangladesh  GDP from Public Administration 2022-06-30  1008.0    Yearly
# 7  Bangladesh  GDP from Public Administration 2023-06-30  1078.9    Yearly
# 8  Bangladesh  GDP from Public Administration 2024-06-30  1139.1    Yearly
# 9  Bangladesh  GDP from Public Administration 2025-06-30  1214.3    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0       BANGLADESHGFPA 2025-05-22 03:17:00
# 1       BANGLADESHGFPA 2025-05-22 03:17:00
# ...

# %%
gdp_from_services = pd.read_csv("../data/tradingeconomics/GDP/GDP_from_Services.csv")

gdp_from_services["DateTime"] = pd.to_datetime(gdp_from_services["DateTime"], errors='coerce')
gdp_from_services["LastUpdate"] = pd.to_datetime(gdp_from_services["LastUpdate"], errors='coerce')

gdp_from_services
# Out:
#       Country           Category   DateTime    Value Frequency  \
# 0  Bangladesh  GDP from Services 2016-06-30  10629.8    Yearly
# 1  Bangladesh  GDP from Services 2017-06-30  11307.5    Yearly
# 2  Bangladesh  GDP from Services 2018-06-30  12048.5    Yearly
# 3  Bangladesh  GDP from Services 2019-06-30  12877.4    Yearly
# 4  Bangladesh  GDP from Services 2020-06-30  13383.9    Yearly
# 5  Bangladesh  GDP from Services 2021-06-30  14151.1    Yearly
# 6  Bangladesh  GDP from Services 2022-06-30  15036.5    Yearly
# 7  Bangladesh  GDP from Services 2023-06-30  15844.1    Yearly
# 8  Bangladesh  GDP from Services 2024-06-30  16650.5    Yearly
# 9  Bangladesh  GDP from Services 2025-06-30  17400.8    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0  BANGLADESHGDPFROSER 2025-05-22 03:19:00
# 1  BANGLADESHGDPFROSER 2025-05-22 03:19:00
# 2  BANGLADESHGDPFROSER 2025-05-22 03:19:00
# 3  BANGLADESHGDPFROSER 2025-05-22 03:19:00
# 4  BANGLADESHGDPFROSER 2025-05-22 03:19:00
# ...

# %%
gdp_from_transport = pd.read_csv("../data/tradingeconomics/GDP/GDP_from_Transport.csv")

gdp_from_transport["DateTime"] = pd.to_datetime(gdp_from_transport["DateTime"], errors='coerce')
gdp_from_transport["LastUpdate"] = pd.to_datetime(gdp_from_transport["LastUpdate"], errors='coerce')

gdp_from_transport
# Out:
#       Country            Category   DateTime   Value Frequency  \
# 0  Bangladesh  GDP from Transport 2016-06-30  1580.3    Yearly
# 1  Bangladesh  GDP from Transport 2017-06-30  1677.1    Yearly
# 2  Bangladesh  GDP from Transport 2018-06-30  1790.1    Yearly
# 3  Bangladesh  GDP from Transport 2019-06-30  1915.6    Yearly
# 4  Bangladesh  GDP from Transport 2020-06-30  1948.7    Yearly
# 5  Bangladesh  GDP from Transport 2021-06-30  2027.4    Yearly
# 6  Bangladesh  GDP from Transport 2022-06-30  2144.0    Yearly
# 7  Bangladesh  GDP from Transport 2023-06-30  2261.6    Yearly
# 8  Bangladesh  GDP from Transport 2024-06-30  2377.9    Yearly
# 9  Bangladesh  GDP from Transport 2025-06-30  2481.8    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0  BANGLADESHGDPFROTRA 2025-05-22 03:21:00
# 1  BANGLADESHGDPFROTRA 2025-05-22 03:21:00
# 2  BANGLADESHGDPFROTRA 2025-05-22 03:21:00
# 3  BANGLADESHGDPFROTRA 2025-05-22 03:21:00
# 4  BANGLADESHGDPFROTRA 2025-05-22 03:21:00
# ...

# %%
gdp_from_utilities = pd.read_csv("../data/tradingeconomics/GDP/GDP_from_utilities.csv")

gdp_from_utilities["DateTime"] = pd.to_datetime(gdp_from_utilities["DateTime"], errors='coerce')
gdp_from_utilities["LastUpdate"] = pd.to_datetime(gdp_from_utilities["LastUpdate"], errors='coerce')

gdp_from_utilities
# Out:
#       Country            Category   DateTime  Value Frequency  \
# 0  Bangladesh  GDP from Utilities 2016-06-30  245.5    Yearly
# 1  Bangladesh  GDP from Utilities 2017-06-30  262.9    Yearly
# 2  Bangladesh  GDP from Utilities 2018-06-30  284.7    Yearly
# 3  Bangladesh  GDP from Utilities 2019-06-30  308.1    Yearly
# 4  Bangladesh  GDP from Utilities 2020-06-30  310.2    Yearly
# 5  Bangladesh  GDP from Utilities 2021-06-30  339.8    Yearly
# 6  Bangladesh  GDP from Utilities 2022-06-30  360.7    Yearly
# 7  Bangladesh  GDP from Utilities 2023-06-30  369.6    Yearly
# 8  Bangladesh  GDP from Utilities 2024-06-30  373.2    Yearly
# 9  Bangladesh  GDP from Utilities 2025-06-30  391.1    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0  BANGLADESHGDPFROUTI 2025-05-22 03:24:00
# 1  BANGLADESHGDPFROUTI 2025-05-22 03:24:00
# 2  BANGLADESHGDPFROUTI 2025-05-22 03:24:00
# 3  BANGLADESHGDPFROUTI 2025-05-22 03:24:00
# 4  BANGLADESHGDPFROUTI 2025-05-22 03:24:00
# ...

# %% [markdown]
# <br> <br>
#
# ## Labor

# %%
unemployment_rate = pd.read_csv("../data/tradingeconomics/Labor/Unemployment_Rate.csv")

unemployment_rate["DateTime"] = pd.to_datetime(unemployment_rate["DateTime"], errors='coerce')
unemployment_rate["LastUpdate"] = pd.to_datetime(unemployment_rate["LastUpdate"], errors='coerce')

unemployment_rate
# Out:
#        Country           Category   DateTime  Value Frequency  \
# 0   Bangladesh  Unemployment Rate 1991-12-31    2.2    Yearly
# 1   Bangladesh  Unemployment Rate 1992-12-31    2.3    Yearly
# 2   Bangladesh  Unemployment Rate 1993-12-31    2.3    Yearly
# 3   Bangladesh  Unemployment Rate 1994-12-31    2.4    Yearly
# 4   Bangladesh  Unemployment Rate 1995-12-31    2.4    Yearly
# 5   Bangladesh  Unemployment Rate 1996-12-31    2.5    Yearly
# 6   Bangladesh  Unemployment Rate 1997-12-31    2.7    Yearly
# 7   Bangladesh  Unemployment Rate 1998-12-31    2.9    Yearly
# 8   Bangladesh  Unemployment Rate 1999-12-31    3.1    Yearly
# 9   Bangladesh  Unemployment Rate 2000-12-31    3.3    Yearly
# 10  Bangladesh  Unemployment Rate 2001-12-31    3.6    Yearly
# 11  Bangladesh  Unemployment Rate 2002-12-31    4.0    Yearly
# 12  Bangladesh  Unemployment Rate 2003-12-31    4.3    Yearly
# 13  Bangladesh  Unemployment Rate 2004-12-31    4.3    Yearly
# ...

# %%
population = pd.read_csv("../data/tradingeconomics/Labor/Population.csv")

population["DateTime"] = pd.to_datetime(population["DateTime"], errors='coerce')
population["LastUpdate"] = pd.to_datetime(population["LastUpdate"], errors='coerce')

population
# Out:
#        Country    Category   DateTime   Value Frequency HistoricalDataSymbol  \
# 0   Bangladesh  Population 1960-12-31   50.10    Yearly      BGD SP.POP.TOTL
# 1   Bangladesh  Population 1961-12-31   51.53    Yearly      BGD SP.POP.TOTL
# 2   Bangladesh  Population 1962-12-31   52.98    Yearly      BGD SP.POP.TOTL
# 3   Bangladesh  Population 1963-12-31   54.47    Yearly      BGD SP.POP.TOTL
# 4   Bangladesh  Population 1964-12-31   56.07    Yearly      BGD SP.POP.TOTL
# ..         ...         ...        ...     ...       ...                  ...
# 60  Bangladesh  Population 2020-12-31  166.30    Yearly      BGD SP.POP.TOTL
# 61  Bangladesh  Population 2021-12-31  167.70    Yearly      BGD SP.POP.TOTL
# 62  Bangladesh  Population 2022-12-31  169.40    Yearly      BGD SP.POP.TOTL
# 63  Bangladesh  Population 2023-12-31  171.50    Yearly      BGD SP.POP.TOTL
# 64  Bangladesh  Population 2024-12-31  171.60    Yearly      BGD SP.POP.TOTL
#
#             LastUpdate
# ...

# %%
minimum_wages = pd.read_csv("../data/tradingeconomics/Labor/Minimum_Wages.csv")

minimum_wages["DateTime"] = pd.to_datetime(minimum_wages["DateTime"], errors='coerce')
minimum_wages["LastUpdate"] = pd.to_datetime(minimum_wages["LastUpdate"], errors='coerce')

minimum_wages
# Out:
#        Country       Category   DateTime  Value Frequency  \
# 0   Bangladesh  Minimum Wages 2014-12-31   5300    Yearly
# 1   Bangladesh  Minimum Wages 2015-12-31   5300    Yearly
# 2   Bangladesh  Minimum Wages 2016-12-31   5300    Yearly
# 3   Bangladesh  Minimum Wages 2017-12-31   5300    Yearly
# 4   Bangladesh  Minimum Wages 2018-12-31   5300    Yearly
# 5   Bangladesh  Minimum Wages 2019-12-31   8000    Yearly
# 6   Bangladesh  Minimum Wages 2020-12-31   8000    Yearly
# 7   Bangladesh  Minimum Wages 2021-12-31   8000    Yearly
# 8   Bangladesh  Minimum Wages 2022-12-31   8000    Yearly
# 9   Bangladesh  Minimum Wages 2023-12-01  12500    Yearly
# 10  Bangladesh  Minimum Wages 2024-12-31  12500    Yearly
# 11  Bangladesh  Minimum Wages 2025-12-31  12500    Yearly
#
#    HistoricalDataSymbol          LastUpdate
# 0      BANGLADESHMINWAG 2018-02-09 14:20:00
# 1      BANGLADESHMINWAG 2018-02-09 14:20:00
# 2      BANGLADESHMINWAG 2018-02-09 14:20:00
# ...

# %%
retirement_age_men = pd.read_csv("../data/tradingeconomics/Labor/Retirement_Age_Men.csv")

retirement_age_men["DateTime"] = pd.to_datetime(retirement_age_men["DateTime"], errors='coerce')
retirement_age_men["LastUpdate"] = pd.to_datetime(retirement_age_men["LastUpdate"], errors='coerce')

retirement_age_men
# Out:
#        Country            Category   DateTime  Value Frequency  \
# 0   Bangladesh  Retirement Age Men 2011-12-31     57    Yearly
# 1   Bangladesh  Retirement Age Men 2012-12-31     59    Yearly
# 2   Bangladesh  Retirement Age Men 2013-12-31     59    Yearly
# 3   Bangladesh  Retirement Age Men 2014-12-31     59    Yearly
# 4   Bangladesh  Retirement Age Men 2015-12-31     59    Yearly
# 5   Bangladesh  Retirement Age Men 2016-12-31     59    Yearly
# 6   Bangladesh  Retirement Age Men 2017-12-31     59    Yearly
# 7   Bangladesh  Retirement Age Men 2018-12-31     59    Yearly
# 8   Bangladesh  Retirement Age Men 2019-12-31     59    Yearly
# 9   Bangladesh  Retirement Age Men 2020-12-31     59    Yearly
# 10  Bangladesh  Retirement Age Men 2021-12-31     59    Yearly
# 11  Bangladesh  Retirement Age Men 2022-12-31     59    Yearly
# 12  Bangladesh  Retirement Age Men 2023-12-31     59    Yearly
# 13  Bangladesh  Retirement Age Men 2024-12-31     59    Yearly
# ...

# %%
retirement_age_women = pd.read_csv("../data/tradingeconomics/Labor/Retirement_Age_Women.csv")

retirement_age_women["DateTime"] = pd.to_datetime(retirement_age_women["DateTime"], errors='coerce')
retirement_age_women["LastUpdate"] = pd.to_datetime(retirement_age_women["LastUpdate"], errors='coerce')

retirement_age_women
# Out:
#        Country              Category   DateTime  Value Frequency  \
# 0   Bangladesh  Retirement Age Women 2011-12-31     57    Yearly
# 1   Bangladesh  Retirement Age Women 2012-12-31     59    Yearly
# 2   Bangladesh  Retirement Age Women 2013-12-31     59    Yearly
# 3   Bangladesh  Retirement Age Women 2014-12-31     59    Yearly
# 4   Bangladesh  Retirement Age Women 2015-12-31     59    Yearly
# 5   Bangladesh  Retirement Age Women 2016-12-31     59    Yearly
# 6   Bangladesh  Retirement Age Women 2017-12-31     59    Yearly
# 7   Bangladesh  Retirement Age Women 2018-12-31     59    Yearly
# 8   Bangladesh  Retirement Age Women 2019-12-31     59    Yearly
# 9   Bangladesh  Retirement Age Women 2020-12-31     59    Yearly
# 10  Bangladesh  Retirement Age Women 2021-12-31     59    Yearly
# 11  Bangladesh  Retirement Age Women 2022-12-31     59    Yearly
# 12  Bangladesh  Retirement Age Women 2023-12-31     59    Yearly
# ...

# %% [markdown]
# <br> <br>
#
# ## Prices

# %%
inflation_rate = pd.read_csv("../data/tradingeconomics/Prices/Inflation_Rate.csv")

inflation_rate["DateTime"] = pd.to_datetime(inflation_rate["DateTime"], errors='coerce')
inflation_rate["LastUpdate"] = pd.to_datetime(inflation_rate["LastUpdate"], errors='coerce')

inflation_rate
# Out:
#         Country        Category   DateTime  Value Frequency  \
# 0    Bangladesh  Inflation Rate 1994-07-31   5.50   Monthly
# 1    Bangladesh  Inflation Rate 1994-08-31   7.11   Monthly
# 2    Bangladesh  Inflation Rate 1994-09-30   6.84   Monthly
# 3    Bangladesh  Inflation Rate 1994-10-31   8.30   Monthly
# 4    Bangladesh  Inflation Rate 1994-11-30   7.62   Monthly
# ..          ...             ...        ...    ...       ...
# 375  Bangladesh  Inflation Rate 2025-08-31   8.29   Monthly
# 376  Bangladesh  Inflation Rate 2025-09-30   8.36   Monthly
# 377  Bangladesh  Inflation Rate 2025-10-31   8.17   Monthly
# 378  Bangladesh  Inflation Rate 2025-11-30   8.29   Monthly
# 379  Bangladesh  Inflation Rate 2025-12-31   8.49   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0           BangladeshIR 2016-04-05 14:51:00
# 1           BangladeshIR 2016-04-05 14:51:00
# 2           BangladeshIR 2016-04-05 14:51:00
# 3           BangladeshIR 2016-04-05 14:51:00
# ...

# %%
consumer_price_index_cpi = pd.read_csv("../data/tradingeconomics/Prices/Consumer_Price_Index_CPI.csv")

consumer_price_index_cpi["DateTime"] = pd.to_datetime(consumer_price_index_cpi["DateTime"], errors='coerce')
consumer_price_index_cpi["LastUpdate"] = pd.to_datetime(consumer_price_index_cpi["LastUpdate"], errors='coerce')

consumer_price_index_cpi
# Out:
#         Country                  Category   DateTime   Value Frequency  \
# 0    Bangladesh  Consumer Price Index CPI 2011-05-31   52.53   Monthly
# 1    Bangladesh  Consumer Price Index CPI 2011-06-30   53.04   Monthly
# 2    Bangladesh  Consumer Price Index CPI 2011-07-31   54.11   Monthly
# 3    Bangladesh  Consumer Price Index CPI 2011-08-31   55.24   Monthly
# 4    Bangladesh  Consumer Price Index CPI 2011-09-30   56.19   Monthly
# ..          ...                       ...        ...     ...       ...
# 171  Bangladesh  Consumer Price Index CPI 2025-08-31  140.06   Monthly
# 172  Bangladesh  Consumer Price Index CPI 2025-09-30  141.53   Monthly
# 173  Bangladesh  Consumer Price Index CPI 2025-10-31  144.21   Monthly
# 174  Bangladesh  Consumer Price Index CPI 2025-11-30  143.65   Monthly
# 175  Bangladesh  Consumer Price Index CPI 2025-12-31  142.44   Monthly
#
#      HistoricalDataSymbol          LastUpdate
# 0    BANGLADESHCONPRIINDC 2023-05-23 13:18:00
# ...

# %%
gdp_deflator = pd.read_csv("../data/tradingeconomics/Prices/GDP_Deflator.csv")

gdp_deflator["DateTime"] = pd.to_datetime(gdp_deflator["DateTime"], errors='coerce')
gdp_deflator["LastUpdate"] = pd.to_datetime(gdp_deflator["LastUpdate"], errors='coerce')

gdp_deflator
# Out:
#        Country      Category   DateTime   Value Frequency  \
# 0   Bangladesh  GDP Deflator 2003-06-30  126.35    Yearly
# 1   Bangladesh  GDP Deflator 2004-06-30  132.93    Yearly
# 2   Bangladesh  GDP Deflator 2005-06-30  138.78    Yearly
# 3   Bangladesh  GDP Deflator 2006-06-30  146.07    Yearly
# 4   Bangladesh  GDP Deflator 2007-06-30  155.95    Yearly
# 5   Bangladesh  GDP Deflator 2008-06-30  168.41    Yearly
# 6   Bangladesh  GDP Deflator 2009-06-30  180.72    Yearly
# 7   Bangladesh  GDP Deflator 2010-06-30  192.42    Yearly
# 8   Bangladesh  GDP Deflator 2011-06-30  206.91    Yearly
# 9   Bangladesh  GDP Deflator 2012-06-30  224.46    Yearly
# 10  Bangladesh  GDP Deflator 2013-06-30  164.26    Yearly
# 11  Bangladesh  GDP Deflator 2014-06-30  173.57    Yearly
# 12  Bangladesh  GDP Deflator 2015-06-30  183.76    Yearly
# 13  Bangladesh  GDP Deflator 2016-06-30  196.13    Yearly
# 14  Bangladesh  GDP Deflator 2017-06-30  208.44    Yearly
# ...

# %%
cpi_transportation = pd.read_csv("../data/tradingeconomics/Prices/CPI_Transportation.csv")

cpi_transportation["DateTime"] = pd.to_datetime(cpi_transportation["DateTime"], errors='coerce')
cpi_transportation["LastUpdate"] = pd.to_datetime(cpi_transportation["LastUpdate"], errors='coerce')

cpi_transportation
# Out:
#        Country            Category   DateTime   Value Frequency  \
# 0   Bangladesh  CPI Transportation 2023-04-30  110.11   Monthly
# 1   Bangladesh  CPI Transportation 2023-05-31  110.38   Monthly
# 2   Bangladesh  CPI Transportation 2023-06-30  110.52   Monthly
# 3   Bangladesh  CPI Transportation 2023-07-31  110.64   Monthly
# 4   Bangladesh  CPI Transportation 2023-08-31  115.73   Monthly
# 5   Bangladesh  CPI Transportation 2023-09-30  116.20   Monthly
# 6   Bangladesh  CPI Transportation 2023-10-31  117.22   Monthly
# 7   Bangladesh  CPI Transportation 2023-11-30  117.85   Monthly
# 8   Bangladesh  CPI Transportation 2023-12-31  118.05   Monthly
# 9   Bangladesh  CPI Transportation 2024-01-31  119.21   Monthly
# 10  Bangladesh  CPI Transportation 2024-02-29  119.31   Monthly
# 11  Bangladesh  CPI Transportation 2024-03-31  119.20   Monthly
# 12  Bangladesh  CPI Transportation 2024-04-30  119.17   Monthly
# 13  Bangladesh  CPI Transportation 2024-05-31  119.33   Monthly
# ...

# %%
food_inflation = pd.read_csv("../data/tradingeconomics/Prices/Food_Inflation.csv")

food_inflation["DateTime"] = pd.to_datetime(food_inflation["DateTime"], errors='coerce')
food_inflation["LastUpdate"] = pd.to_datetime(food_inflation["LastUpdate"], errors='coerce')

food_inflation
# Out:
#         Country        Category   DateTime  Value Frequency  \
# 0    Bangladesh  Food Inflation 2013-04-30   8.68   Monthly
# 1    Bangladesh  Food Inflation 2013-05-31   8.13   Monthly
# 2    Bangladesh  Food Inflation 2013-06-30   8.26   Monthly
# 3    Bangladesh  Food Inflation 2013-07-31   8.09   Monthly
# 4    Bangladesh  Food Inflation 2013-08-31   7.93   Monthly
# ..          ...             ...        ...    ...       ...
# 147  Bangladesh  Food Inflation 2025-08-31   7.60   Monthly
# 148  Bangladesh  Food Inflation 2025-09-30   7.64   Monthly
# 149  Bangladesh  Food Inflation 2025-10-31   7.08   Monthly
# 150  Bangladesh  Food Inflation 2025-11-30   7.36   Monthly
# 151  Bangladesh  Food Inflation 2025-12-31   7.71   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0       BANGLADESHFOOINF 2014-06-30 13:29:00
# 1       BANGLADESHFOOINF 2014-06-30 13:29:00
# 2       BANGLADESHFOOINF 2014-07-15 17:18:00
# 3       BANGLADESHFOOINF 2014-06-30 13:29:00
# ...

# %%
inflation_rate_mom = pd.read_csv("../data/tradingeconomics/Prices/Inflation_Rate_MoM.csv")

inflation_rate_mom["DateTime"] = pd.to_datetime(inflation_rate_mom["DateTime"], errors='coerce')
inflation_rate_mom["LastUpdate"] = pd.to_datetime(inflation_rate_mom["LastUpdate"], errors='coerce')

inflation_rate_mom
# Out:
#         Country            Category   DateTime  Value Frequency  \
# 0    Bangladesh  Inflation Rate MoM 2011-06-30   0.98   Monthly
# 1    Bangladesh  Inflation Rate MoM 2011-07-31   2.01   Monthly
# 2    Bangladesh  Inflation Rate MoM 2011-08-31   2.08   Monthly
# 3    Bangladesh  Inflation Rate MoM 2011-09-30   1.72   Monthly
# 4    Bangladesh  Inflation Rate MoM 2011-10-31   0.15   Monthly
# ..          ...                 ...        ...    ...       ...
# 169  Bangladesh  Inflation Rate MoM 2025-08-31   2.36   Monthly
# 170  Bangladesh  Inflation Rate MoM 2025-09-30   1.05   Monthly
# 171  Bangladesh  Inflation Rate MoM 2025-10-31   1.89   Monthly
# 172  Bangladesh  Inflation Rate MoM 2025-11-30  -0.39   Monthly
# 173  Bangladesh  Inflation Rate MoM 2025-12-31  -0.84   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0    BANGLADESHINFRATMOM 2014-08-26 14:42:00
# 1    BANGLADESHINFRATMOM 2014-08-26 14:42:00
# 2    BANGLADESHINFRATMOM 2014-08-26 14:42:00
# ...

# %% [markdown]
# <br> <br>
#
# ## Money

# %%
interest_rate = pd.read_csv("../data/tradingeconomics/Money/Interest_Rate.csv")

interest_rate["DateTime"] = pd.to_datetime(interest_rate["DateTime"], errors='coerce')
interest_rate["LastUpdate"] = pd.to_datetime(interest_rate["LastUpdate"], errors='coerce')

interest_rate
# Out:
#         Country       Category   DateTime  Value Frequency  \
# 0    Bangladesh  Interest Rate 2008-01-31    8.5     Daily
# 1    Bangladesh  Interest Rate 2008-02-29    8.5     Daily
# 2    Bangladesh  Interest Rate 2008-03-31    8.5     Daily
# 3    Bangladesh  Interest Rate 2008-04-30    8.5     Daily
# 4    Bangladesh  Interest Rate 2008-05-31    8.5     Daily
# ..          ...            ...        ...    ...       ...
# 211  Bangladesh  Interest Rate 2025-08-31   10.0     Daily
# 212  Bangladesh  Interest Rate 2025-09-30   10.0     Daily
# 213  Bangladesh  Interest Rate 2025-10-31   10.0     Daily
# 214  Bangladesh  Interest Rate 2025-11-30   10.0     Daily
# 215  Bangladesh  Interest Rate 2025-12-31   10.0     Daily
#
#     HistoricalDataSymbol          LastUpdate
# 0      BangladeshIntRate 2011-06-27 00:00:00
# 1      BangladeshIntRate 2011-06-27 00:00:00
# 2      BangladeshIntRate 2011-06-27 00:00:00
# 3      BangladeshIntRate 2011-06-27 00:00:00
# ...

# %%
interbank_rate = pd.read_csv("../data/tradingeconomics/Money/Interbank_Rate.csv")

interbank_rate["DateTime"] = pd.to_datetime(interbank_rate["DateTime"], errors='coerce')
interbank_rate["LastUpdate"] = pd.to_datetime(interbank_rate["LastUpdate"], errors='coerce')

interbank_rate
# Out:
#         Country        Category   DateTime  Value Frequency  \
# 0    Bangladesh  Interbank Rate 1997-01-31   5.87   Monthly
# 1    Bangladesh  Interbank Rate 1997-02-28   7.63   Monthly
# 2    Bangladesh  Interbank Rate 1997-03-31   6.97   Monthly
# 3    Bangladesh  Interbank Rate 1997-04-30   8.94   Monthly
# 4    Bangladesh  Interbank Rate 1997-05-30   8.46   Monthly
# ..          ...             ...        ...    ...       ...
# 343  Bangladesh  Interbank Rate 2025-08-31   9.98   Monthly
# 344  Bangladesh  Interbank Rate 2025-09-30   9.97   Monthly
# 345  Bangladesh  Interbank Rate 2025-10-31   9.74   Monthly
# 346  Bangladesh  Interbank Rate 2025-11-30   9.79   Monthly
# 347  Bangladesh  Interbank Rate 2025-12-31   9.99   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0       BANGLADESHINTRAT 2015-04-30 13:11:00
# 1       BANGLADESHINTRAT 2015-04-30 13:11:00
# 2       BANGLADESHINTRAT 2015-04-30 13:11:00
# 3       BANGLADESHINTRAT 2015-04-30 13:11:00
# ...

# %%
money_supply_m0 = pd.read_csv("../data/tradingeconomics/Money/Money_Supply_M0.csv")

money_supply_m0["DateTime"] = pd.to_datetime(money_supply_m0["DateTime"], errors='coerce')
money_supply_m0["LastUpdate"] = pd.to_datetime(money_supply_m0["LastUpdate"], errors='coerce')

money_supply_m0
# Out:
#         Country         Category   DateTime    Value Frequency  \
# 0    Bangladesh  Money Supply M0 1990-07-31    35.93   Monthly
# 1    Bangladesh  Money Supply M0 1990-08-31    35.13   Monthly
# 2    Bangladesh  Money Supply M0 1990-09-30    35.26   Monthly
# 3    Bangladesh  Money Supply M0 1990-10-31    34.50   Monthly
# 4    Bangladesh  Money Supply M0 1990-11-30    34.38   Monthly
# ..          ...              ...        ...      ...       ...
# 418  Bangladesh  Money Supply M0 2025-06-30  3266.97   Monthly
# 419  Bangladesh  Money Supply M0 2025-07-31  3153.10   Monthly
# 420  Bangladesh  Money Supply M0 2025-08-31  3069.96   Monthly
# 421  Bangladesh  Money Supply M0 2025-09-30  3034.86   Monthly
# 422  Bangladesh  Money Supply M0 2025-10-31  2987.60   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0     BANGLADESHMONSUPM0 2014-11-16 21:32:00
# 1     BANGLADESHMONSUPM0 2012-09-28 19:03:00
# 2     BANGLADESHMONSUPM0 2014-11-16 21:32:00
# ...

# %%
money_supply_m1 = pd.read_csv("../data/tradingeconomics/Money/Money_Supply_M1.csv")

money_supply_m1["DateTime"] = pd.to_datetime(money_supply_m1["DateTime"], errors='coerce')
money_supply_m1["LastUpdate"] = pd.to_datetime(money_supply_m1["LastUpdate"], errors='coerce')

money_supply_m1
# Out:
#         Country         Category   DateTime     Value Frequency  \
# 0    Bangladesh  Money Supply M1 1974-06-30     7.177   Monthly
# 1    Bangladesh  Money Supply M1 1974-07-31     6.949   Monthly
# 2    Bangladesh  Money Supply M1 1974-08-31     6.951   Monthly
# 3    Bangladesh  Money Supply M1 1974-09-30     7.049   Monthly
# 4    Bangladesh  Money Supply M1 1974-10-31     7.474   Monthly
# ..          ...              ...        ...       ...       ...
# 613  Bangladesh  Money Supply M1 2025-07-31  4853.470   Monthly
# 614  Bangladesh  Money Supply M1 2025-08-31  4778.330   Monthly
# 615  Bangladesh  Money Supply M1 2025-09-30  4708.970   Monthly
# 616  Bangladesh  Money Supply M1 2025-10-31  4661.170   Monthly
# 617  Bangladesh  Money Supply M1 2025-11-30  4717.410   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0     BANGLADESHMONSUPM1 2025-03-07 09:43:00
# 1     BANGLADESHMONSUPM1 2025-03-07 09:43:00
# 2     BANGLADESHMONSUPM1 2025-03-07 09:43:00
# ...

# %%
money_supply_m2 = pd.read_csv("../data/tradingeconomics/Money/Money_Supply_M2.csv")

money_supply_m2["DateTime"] = pd.to_datetime(money_supply_m2["DateTime"], errors='coerce')
money_supply_m2["LastUpdate"] = pd.to_datetime(money_supply_m2["LastUpdate"], errors='coerce')

money_supply_m2
# Out:
#         Country         Category   DateTime     Value Frequency  \
# 0    Bangladesh  Money Supply M2 1990-01-31    208.34   Monthly
# 1    Bangladesh  Money Supply M2 1990-02-28    209.14   Monthly
# 2    Bangladesh  Money Supply M2 1990-03-31    207.37   Monthly
# 3    Bangladesh  Money Supply M2 1990-04-30    209.33   Monthly
# 4    Bangladesh  Money Supply M2 1990-05-31    208.03   Monthly
# ..          ...              ...        ...       ...       ...
# 425  Bangladesh  Money Supply M2 2025-07-31  21679.00   Monthly
# 426  Bangladesh  Money Supply M2 2025-08-31  21817.70   Monthly
# 427  Bangladesh  Money Supply M2 2025-09-30  21899.90   Monthly
# 428  Bangladesh  Money Supply M2 2025-10-31  21950.90   Monthly
# 429  Bangladesh  Money Supply M2 2025-11-30  22228.10   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0     BANGLADESHMONSUPM2 2012-09-28 19:03:00
# 1     BANGLADESHMONSUPM2 2012-09-28 19:03:00
# 2     BANGLADESHMONSUPM2 2012-09-28 19:03:00
# ...

# %%
money_supply_m3 = pd.read_csv("../data/tradingeconomics/Money/Money_Supply_M3.csv")

money_supply_m3["DateTime"] = pd.to_datetime(money_supply_m3["DateTime"], errors='coerce')
money_supply_m3["LastUpdate"] = pd.to_datetime(money_supply_m3["LastUpdate"], errors='coerce')

money_supply_m3
# Out:
#         Country         Category   DateTime     Value Frequency  \
# 0    Bangladesh  Money Supply M3 1999-01-29    73.632   Monthly
# 1    Bangladesh  Money Supply M3 1999-02-28    73.298   Monthly
# 2    Bangladesh  Money Supply M3 1999-03-31    74.111   Monthly
# 3    Bangladesh  Money Supply M3 1999-04-30    74.566   Monthly
# 4    Bangladesh  Money Supply M3 1999-05-31    74.295   Monthly
# ..          ...              ...        ...       ...       ...
# 318  Bangladesh  Money Supply M3 2025-06-30  2552.901   Monthly
# 319  Bangladesh  Money Supply M3 2025-07-31  2546.855   Monthly
# 320  Bangladesh  Money Supply M3 2025-08-31  2560.875   Monthly
# 321  Bangladesh  Money Supply M3 2025-09-30  2568.886   Monthly
# 322  Bangladesh  Money Supply M3 2025-10-31  2575.440   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0     BANGLADESHMONSUPM3 2025-03-07 09:49:00
# 1     BANGLADESHMONSUPM3 2025-03-07 09:49:00
# 2     BANGLADESHMONSUPM3 2025-03-07 09:49:00
# ...

# %%
foreign_exchange_reserves = pd.read_csv("../data/tradingeconomics/Money/Foreign_Exchange_Reserves.csv")

foreign_exchange_reserves["DateTime"] = pd.to_datetime(foreign_exchange_reserves["DateTime"], errors='coerce')
foreign_exchange_reserves["LastUpdate"] = pd.to_datetime(foreign_exchange_reserves["LastUpdate"], errors='coerce')

foreign_exchange_reserves
# Out:
#         Country                   Category   DateTime    Value Frequency  \
# 0    Bangladesh  Foreign Exchange Reserves 2008-06-30   7470.9   Monthly
# 1    Bangladesh  Foreign Exchange Reserves 2008-07-31   7741.5   Monthly
# 2    Bangladesh  Foreign Exchange Reserves 2008-08-31   9155.7   Monthly
# 3    Bangladesh  Foreign Exchange Reserves 2008-09-30   9362.6   Monthly
# 4    Bangladesh  Foreign Exchange Reserves 2008-10-31   9544.7   Monthly
# ..          ...                        ...        ...      ...       ...
# 206  Bangladesh  Foreign Exchange Reserves 2025-08-31  31166.2   Monthly
# 207  Bangladesh  Foreign Exchange Reserves 2025-09-30  31426.8   Monthly
# 208  Bangladesh  Foreign Exchange Reserves 2025-10-31  32335.2   Monthly
# 209  Bangladesh  Foreign Exchange Reserves 2025-11-30  31093.4   Monthly
# 210  Bangladesh  Foreign Exchange Reserves 2025-12-31  33187.9   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0    BANGLADESHFOREXCRES 2016-07-20 16:02:00
# ...

# %%
loans_to_private_sector = pd.read_csv("../data/tradingeconomics/Money/Loans_to_Private_Sector.csv")

loans_to_private_sector["DateTime"] = pd.to_datetime(loans_to_private_sector["DateTime"], errors='coerce')
loans_to_private_sector["LastUpdate"] = pd.to_datetime(loans_to_private_sector["LastUpdate"], errors='coerce')

loans_to_private_sector
# Out:
#         Country                 Category   DateTime     Value Frequency  \
# 0    Bangladesh  Loans to Private Sector 1990-07-31    152.33   Monthly
# 1    Bangladesh  Loans to Private Sector 1990-08-31    154.84   Monthly
# 2    Bangladesh  Loans to Private Sector 1990-09-30    158.04   Monthly
# 3    Bangladesh  Loans to Private Sector 1990-10-31    156.06   Monthly
# 4    Bangladesh  Loans to Private Sector 1990-11-30    157.02   Monthly
# ..          ...                      ...        ...       ...       ...
# 480  Bangladesh  Loans to Private Sector 2025-06-30  16815.93   Monthly
# 481  Bangladesh  Loans to Private Sector 2025-07-31  16777.13   Monthly
# 482  Bangladesh  Loans to Private Sector 2025-08-31  16807.89   Monthly
# 483  Bangladesh  Loans to Private Sector 2025-09-30  16894.61   Monthly
# 484  Bangladesh  Loans to Private Sector 2025-10-31  16921.93   Monthly
#
#      HistoricalDataSymbol          LastUpdate
# 0    BANGLADESHLOATOPRISE 2014-11-16 21:32:00
# ...

# %%
deposit_interest_rate = pd.read_csv("../data/tradingeconomics/Money/Deposit_Interest_Rate.csv")

deposit_interest_rate["DateTime"] = pd.to_datetime(deposit_interest_rate["DateTime"], errors='coerce')
deposit_interest_rate["LastUpdate"] = pd.to_datetime(deposit_interest_rate["LastUpdate"], errors='coerce')

deposit_interest_rate
# Out:
#        Country               Category   DateTime  Value Frequency  \
# 0   Bangladesh  Deposit Interest Rate 1980-12-31   8.25    Yearly
# 1   Bangladesh  Deposit Interest Rate 1981-12-31  12.00    Yearly
# 2   Bangladesh  Deposit Interest Rate 1982-12-31  12.00    Yearly
# 3   Bangladesh  Deposit Interest Rate 1983-12-31  12.00    Yearly
# 4   Bangladesh  Deposit Interest Rate 1984-12-31  12.00    Yearly
# 5   Bangladesh  Deposit Interest Rate 1985-12-31  12.00    Yearly
# 6   Bangladesh  Deposit Interest Rate 1986-12-31  12.00    Yearly
# 7   Bangladesh  Deposit Interest Rate 1987-12-31  12.00    Yearly
# 8   Bangladesh  Deposit Interest Rate 1988-12-31  12.00    Yearly
# 9   Bangladesh  Deposit Interest Rate 1989-12-31  12.00    Yearly
# 10  Bangladesh  Deposit Interest Rate 1990-12-31  12.04    Yearly
# 11  Bangladesh  Deposit Interest Rate 1991-12-31  12.05    Yearly
# 12  Bangladesh  Deposit Interest Rate 1992-12-31  10.47    Yearly
# ...

# %% [markdown]
# <br> <br>
#
# ## Trade

# %%
balance_of_trade = pd.read_csv("../data/tradingeconomics/Trade/Balance_of_Trade.csv")

balance_of_trade["DateTime"] = pd.to_datetime(balance_of_trade["DateTime"], errors='coerce')
balance_of_trade["LastUpdate"] = pd.to_datetime(balance_of_trade["LastUpdate"], errors='coerce')

balance_of_trade
# Out:
#         Country          Category   DateTime   Value Frequency  \
# 0    Bangladesh  Balance of Trade 1976-03-31   -1.20   Monthly
# 1    Bangladesh  Balance of Trade 1976-04-30   -0.60   Monthly
# 2    Bangladesh  Balance of Trade 1976-05-31   -0.60   Monthly
# 3    Bangladesh  Balance of Trade 1976-06-30   -1.40   Monthly
# 4    Bangladesh  Balance of Trade 1976-07-31   -0.70   Monthly
# ..          ...               ...        ...     ...       ...
# 589  Bangladesh  Balance of Trade 2025-06-30 -181.83   Monthly
# 590  Bangladesh  Balance of Trade 2025-07-31 -211.58   Monthly
# 591  Bangladesh  Balance of Trade 2025-08-31 -118.86   Monthly
# 592  Bangladesh  Balance of Trade 2025-09-30 -203.34   Monthly
# 593  Bangladesh  Balance of Trade 2025-10-31 -219.48   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0           BangladeshBT 2014-08-26 18:11:00
# 1           BangladeshBT 2014-08-26 18:11:00
# 2           BangladeshBT 2014-11-16 21:27:00
# ...

# %%
current_account = pd.read_csv("../data/tradingeconomics/Trade/Current_Account.csv")

current_account["DateTime"] = pd.to_datetime(current_account["DateTime"], errors='coerce')
current_account["LastUpdate"] = pd.to_datetime(current_account["LastUpdate"], errors='coerce')

current_account
# Out:
#         Country         Category   DateTime    Value Frequency  \
# 0    Bangladesh  Current Account 2005-06-30  -557.00   Monthly
# 1    Bangladesh  Current Account 2006-06-30   824.00   Monthly
# 2    Bangladesh  Current Account 2007-06-30   952.00   Monthly
# 3    Bangladesh  Current Account 2008-06-30   680.00   Monthly
# 4    Bangladesh  Current Account 2008-09-30   366.00   Monthly
# ..          ...              ...        ...      ...       ...
# 174  Bangladesh  Current Account 2025-05-31  1126.51   Monthly
# 175  Bangladesh  Current Account 2025-06-30   734.36   Monthly
# 176  Bangladesh  Current Account 2025-07-31   300.46   Monthly
# 177  Bangladesh  Current Account 2025-08-31   294.02   Monthly
# 178  Bangladesh  Current Account 2025-09-30 -1129.87   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0           BangladeshCA 2011-06-27 00:00:00
# 1           BangladeshCA 2011-06-27 00:00:00
# 2           BangladeshCA 2011-06-27 00:00:00
# ...

# %%
current_account_to_gdp = pd.read_csv("../data/tradingeconomics/Trade/Current_Account_to_GDP.csv")

current_account_to_gdp["DateTime"] = pd.to_datetime(current_account_to_gdp["DateTime"], errors='coerce')
current_account_to_gdp["LastUpdate"] = pd.to_datetime(current_account_to_gdp["LastUpdate"], errors='coerce')

current_account_to_gdp
# Out:
#        Country                Category   DateTime  Value Frequency  \
# 0   Bangladesh  Current Account to GDP 1980-12-31   -0.8    Yearly
# 1   Bangladesh  Current Account to GDP 1981-12-31   -1.8    Yearly
# 2   Bangladesh  Current Account to GDP 1982-12-31   -2.7    Yearly
# 3   Bangladesh  Current Account to GDP 1983-12-31   -2.2    Yearly
# 4   Bangladesh  Current Account to GDP 1984-12-31   -1.9    Yearly
# 5   Bangladesh  Current Account to GDP 1985-12-31   -2.4    Yearly
# 6   Bangladesh  Current Account to GDP 1986-12-31   -2.2    Yearly
# 7   Bangladesh  Current Account to GDP 1987-12-31   -1.7    Yearly
# 8   Bangladesh  Current Account to GDP 1988-12-31   -2.4    Yearly
# 9   Bangladesh  Current Account to GDP 1989-12-31   -3.2    Yearly
# 10  Bangladesh  Current Account to GDP 1990-12-31   -2.7    Yearly
# 11  Bangladesh  Current Account to GDP 1991-12-31   -1.5    Yearly
# 12  Bangladesh  Current Account to GDP 1992-12-31   -0.5    Yearly
# ...

# %%
exports = pd.read_csv("../data/tradingeconomics/Trade/Exports.csv")

exports["DateTime"] = pd.to_datetime(exports["DateTime"], errors='coerce')
exports["LastUpdate"] = pd.to_datetime(exports["LastUpdate"], errors='coerce')

exports
# Out:
#         Country Category   DateTime   Value Frequency HistoricalDataSymbol  \
# 0    Bangladesh  Exports 1972-01-31    0.09   Monthly         BangladeshEx
# 1    Bangladesh  Exports 1972-02-29    0.05   Monthly         BangladeshEx
# 2    Bangladesh  Exports 1972-03-31    0.13   Monthly         BangladeshEx
# 3    Bangladesh  Exports 1972-04-30    0.13   Monthly         BangladeshEx
# 4    Bangladesh  Exports 1972-05-31    0.22   Monthly         BangladeshEx
# ..          ...      ...        ...     ...       ...                  ...
# 639  Bangladesh  Exports 2025-06-30  407.54   Monthly         BangladeshEx
# 640  Bangladesh  Exports 2025-07-31  484.73   Monthly         BangladeshEx
# 641  Bangladesh  Exports 2025-08-31  462.35   Monthly         BangladeshEx
# 642  Bangladesh  Exports 2025-09-30  447.21   Monthly         BangladeshEx
# 643  Bangladesh  Exports 2025-10-31  420.37   Monthly         BangladeshEx
#
#              LastUpdate
# 0   2014-11-16 21:29:00
# ...

# %%
imports = pd.read_csv("../data/tradingeconomics/Trade/Imports.csv")

imports["DateTime"] = pd.to_datetime(imports["DateTime"], errors='coerce')
imports["LastUpdate"] = pd.to_datetime(imports["LastUpdate"], errors='coerce')

imports
# Out:
#         Country Category   DateTime   Value Frequency HistoricalDataSymbol  \
# 0    Bangladesh  Imports 1976-03-31    1.74   Monthly         BangladeshIm
# 1    Bangladesh  Imports 1976-04-30    1.02   Monthly         BangladeshIm
# 2    Bangladesh  Imports 1976-05-31    1.20   Monthly         BangladeshIm
# 3    Bangladesh  Imports 1976-06-30    1.98   Monthly         BangladeshIm
# 4    Bangladesh  Imports 1976-07-31    1.27   Monthly         BangladeshIm
# ..          ...      ...        ...     ...       ...                  ...
# 589  Bangladesh  Imports 2025-06-30  589.38   Monthly         BangladeshIm
# 590  Bangladesh  Imports 2025-07-31  696.31   Monthly         BangladeshIm
# 591  Bangladesh  Imports 2025-08-31  581.21   Monthly         BangladeshIm
# 592  Bangladesh  Imports 2025-09-30  650.55   Monthly         BangladeshIm
# 593  Bangladesh  Imports 2025-10-31  639.85   Monthly         BangladeshIm
#
#              LastUpdate
# 0   2014-08-26 18:10:00
# ...

# %%
capital_flows = pd.read_csv("../data/tradingeconomics/Trade/Capital_Flows.csv")

capital_flows["DateTime"] = pd.to_datetime(capital_flows["DateTime"], errors='coerce')
capital_flows["LastUpdate"] = pd.to_datetime(capital_flows["LastUpdate"], errors='coerce')

capital_flows
# Out:
#         Country       Category   DateTime   Value Frequency  \
# 0    Bangladesh  Capital Flows 1997-07-31  -4.420   Monthly
# 1    Bangladesh  Capital Flows 1997-08-31   2.110   Monthly
# 2    Bangladesh  Capital Flows 1997-09-30  -5.910   Monthly
# 3    Bangladesh  Capital Flows 1997-10-31   0.620   Monthly
# 4    Bangladesh  Capital Flows 1997-11-30  -1.150   Monthly
# ..          ...            ...        ...     ...       ...
# 328  Bangladesh  Capital Flows 2025-05-31   2.850   Monthly
# 329  Bangladesh  Capital Flows 2025-06-30   6.860   Monthly
# 330  Bangladesh  Capital Flows 2025-07-31   0.040   Monthly
# 331  Bangladesh  Capital Flows 2025-08-31   1.004   Monthly
# 332  Bangladesh  Capital Flows 2025-09-30  10.340   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0       BANGLADESHCAPFLO 2014-05-02 16:52:00
# 1       BANGLADESHCAPFLO 2014-05-02 16:52:00
# 2       BANGLADESHCAPFLO 2014-05-02 16:52:00
# 3       BANGLADESHCAPFLO 2014-05-02 16:52:00
# ...

# %%
remittances = pd.read_csv("../data/tradingeconomics/Trade/Remittances.csv")

remittances["DateTime"] = pd.to_datetime(remittances["DateTime"], errors='coerce')
remittances["LastUpdate"] = pd.to_datetime(remittances["LastUpdate"], errors='coerce')

remittances
# Out:
#         Country     Category   DateTime    Value Frequency  \
# 0    Bangladesh  Remittances 2012-02-29  1133.00   Monthly
# 1    Bangladesh  Remittances 2012-03-31  1109.10   Monthly
# 2    Bangladesh  Remittances 2012-04-30  1083.90   Monthly
# 3    Bangladesh  Remittances 2012-05-31  1156.80   Monthly
# 4    Bangladesh  Remittances 2012-06-30  1070.90   Monthly
# ..          ...          ...        ...      ...       ...
# 160  Bangladesh  Remittances 2025-06-30  2822.53   Monthly
# 161  Bangladesh  Remittances 2025-07-31  2477.87   Monthly
# 162  Bangladesh  Remittances 2025-08-31  2421.89   Monthly
# 163  Bangladesh  Remittances 2025-09-30  2685.56   Monthly
# 164  Bangladesh  Remittances 2025-10-31  2562.44   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0          BANGLADESHREM 2013-10-09 10:13:00
# 1          BANGLADESHREM 2013-10-09 10:13:00
# 2          BANGLADESHREM 2013-10-09 10:13:00
# 3          BANGLADESHREM 2013-10-09 10:13:00
# ...

# %%
gold_reserves = pd.read_csv("../data/tradingeconomics/Trade/Gold_Reserves.csv")

gold_reserves["DateTime"] = pd.to_datetime(gold_reserves["DateTime"], errors='coerce')
gold_reserves["LastUpdate"] = pd.to_datetime(gold_reserves["LastUpdate"], errors='coerce')

gold_reserves
# Out:
#         Country       Category   DateTime  Value  Frequency  \
# 0    Bangladesh  Gold Reserves 2000-03-31   3.29  Quarterly
# 1    Bangladesh  Gold Reserves 2000-06-30   3.34  Quarterly
# 2    Bangladesh  Gold Reserves 2000-09-30   3.34  Quarterly
# 3    Bangladesh  Gold Reserves 2000-12-31   3.38  Quarterly
# 4    Bangladesh  Gold Reserves 2001-03-31   3.38  Quarterly
# ..          ...            ...        ...    ...        ...
# 99   Bangladesh  Gold Reserves 2024-09-30  14.26  Quarterly
# 100  Bangladesh  Gold Reserves 2024-12-31  14.28  Quarterly
# 101  Bangladesh  Gold Reserves 2025-03-31  14.28  Quarterly
# 102  Bangladesh  Gold Reserves 2025-06-30  14.28  Quarterly
# 103  Bangladesh  Gold Reserves 2025-09-30  14.28  Quarterly
#
#     HistoricalDataSymbol          LastUpdate
# 0       BANGLADESHGOLRES 2014-04-16 18:42:00
# 1       BANGLADESHGOLRES 2014-04-16 18:42:00
# 2       BANGLADESHGOLRES 2014-04-16 18:42:00
# 3       BANGLADESHGOLRES 2014-04-16 18:42:00
# ...

# %%
external_debt = pd.read_csv("../data/tradingeconomics/Trade/External_Debt.csv")

external_debt["DateTime"] = pd.to_datetime(external_debt["DateTime"], errors='coerce')
external_debt["LastUpdate"] = pd.to_datetime(external_debt["LastUpdate"], errors='coerce')

external_debt
# Out:
#        Country       Category   DateTime  Value Frequency  \
# 0   Bangladesh  External Debt 2001-12-31  16.24    Yearly
# 1   Bangladesh  External Debt 2002-12-31  16.17    Yearly
# 2   Bangladesh  External Debt 2003-12-31  17.00    Yearly
# 3   Bangladesh  External Debt 2004-12-31  18.00    Yearly
# 4   Bangladesh  External Debt 2005-12-31  18.41    Yearly
# 5   Bangladesh  External Debt 2006-12-31  18.60    Yearly
# 6   Bangladesh  External Debt 2007-12-31  19.35    Yearly
# 7   Bangladesh  External Debt 2008-12-31  20.26    Yearly
# 8   Bangladesh  External Debt 2009-12-31  20.86    Yearly
# 9   Bangladesh  External Debt 2010-12-31  20.34    Yearly
# 10  Bangladesh  External Debt 2011-12-31  22.10    Yearly
# 11  Bangladesh  External Debt 2012-12-31  22.10    Yearly
# 12  Bangladesh  External Debt 2013-12-31  22.40    Yearly
# 13  Bangladesh  External Debt 2014-12-31  24.40    Yearly
# 14  Bangladesh  External Debt 2015-12-31  23.90    Yearly
# ...

# %%
foreign_direct_investment = pd.read_csv("../data/tradingeconomics/Trade/Foreign_Direct_Investment.csv")

foreign_direct_investment["DateTime"] = pd.to_datetime(foreign_direct_investment["DateTime"], errors='coerce')
foreign_direct_investment["LastUpdate"] = pd.to_datetime(foreign_direct_investment["LastUpdate"], errors='coerce')

foreign_direct_investment
# Out:
#        Country                   Category   DateTime  Value Frequency  \
# 0   Bangladesh  Foreign Direct Investment 2002-12-31    391    Yearly
# 1   Bangladesh  Foreign Direct Investment 2003-12-31    376    Yearly
# 2   Bangladesh  Foreign Direct Investment 2004-12-31    276    Yearly
# 3   Bangladesh  Foreign Direct Investment 2005-12-31    800    Yearly
# 4   Bangladesh  Foreign Direct Investment 2006-12-31    743    Yearly
# 5   Bangladesh  Foreign Direct Investment 2007-12-31    793    Yearly
# 6   Bangladesh  Foreign Direct Investment 2008-12-31    748    Yearly
# 7   Bangladesh  Foreign Direct Investment 2009-12-31    961    Yearly
# 8   Bangladesh  Foreign Direct Investment 2010-12-31    913    Yearly
# 9   Bangladesh  Foreign Direct Investment 2011-12-31    775    Yearly
# 10  Bangladesh  Foreign Direct Investment 2012-12-31   1191    Yearly
# 11  Bangladesh  Foreign Direct Investment 2013-12-31   1726    Yearly
# ...

# %%
terrorism_index = pd.read_csv("../data/tradingeconomics/Trade/Terrorism_Index.csv")

terrorism_index["DateTime"] = pd.to_datetime(terrorism_index["DateTime"], errors='coerce')
terrorism_index["LastUpdate"] = pd.to_datetime(terrorism_index["LastUpdate"], errors='coerce')

terrorism_index
# Out:
#        Country         Category   DateTime  Value Frequency  \
# 0   Bangladesh  Terrorism Index 2002-12-31  5.340    Yearly
# 1   Bangladesh  Terrorism Index 2003-12-31  4.760    Yearly
# 2   Bangladesh  Terrorism Index 2004-12-31  5.030    Yearly
# 3   Bangladesh  Terrorism Index 2005-12-31  5.510    Yearly
# 4   Bangladesh  Terrorism Index 2006-12-31  5.250    Yearly
# 5   Bangladesh  Terrorism Index 2007-12-31  4.670    Yearly
# 6   Bangladesh  Terrorism Index 2008-12-31  4.510    Yearly
# 7   Bangladesh  Terrorism Index 2009-12-31  4.510    Yearly
# 8   Bangladesh  Terrorism Index 2010-12-31  4.620    Yearly
# 9   Bangladesh  Terrorism Index 2011-12-31  4.229    Yearly
# 10  Bangladesh  Terrorism Index 2012-12-31  4.460    Yearly
# 11  Bangladesh  Terrorism Index 2013-12-31  4.527    Yearly
# 12  Bangladesh  Terrorism Index 2014-12-31  4.191    Yearly
# 13  Bangladesh  Terrorism Index 2015-12-31  5.392    Yearly
# 14  Bangladesh  Terrorism Index 2016-12-31  5.752    Yearly
# ...

# %% [markdown]
# <br> <br>
#
# ## Government

# %%
government_debt_to_gdp = pd.read_csv("../data/tradingeconomics/Government/Government_Debt_to_GDP.csv")

government_debt_to_gdp["DateTime"] = pd.to_datetime(government_debt_to_gdp["DateTime"], errors='coerce')
government_debt_to_gdp["LastUpdate"] = pd.to_datetime(government_debt_to_gdp["LastUpdate"], errors='coerce')

government_debt_to_gdp
# Out:
#        Country                Category   DateTime  Value Frequency  \
# 0   Bangladesh  Government Debt to GDP 1995-12-31   49.0    Yearly
# 1   Bangladesh  Government Debt to GDP 1996-12-31   43.9    Yearly
# 2   Bangladesh  Government Debt to GDP 1997-12-31   43.2    Yearly
# 3   Bangladesh  Government Debt to GDP 1998-12-31   40.4    Yearly
# 4   Bangladesh  Government Debt to GDP 1999-12-31   42.4    Yearly
# 5   Bangladesh  Government Debt to GDP 2000-12-31   46.4    Yearly
# 6   Bangladesh  Government Debt to GDP 2001-12-31   46.2    Yearly
# 7   Bangladesh  Government Debt to GDP 2002-12-31   50.0    Yearly
# 8   Bangladesh  Government Debt to GDP 2003-12-31   49.0    Yearly
# 9   Bangladesh  Government Debt to GDP 2004-12-31   48.2    Yearly
# 10  Bangladesh  Government Debt to GDP 2005-12-31   46.9    Yearly
# 11  Bangladesh  Government Debt to GDP 2006-12-31   40.2    Yearly
# 12  Bangladesh  Government Debt to GDP 2007-12-31   38.6    Yearly
# ...

# %%
government_budget = pd.read_csv("../data/tradingeconomics/Government/Government_Budget.csv")

government_budget["DateTime"] = pd.to_datetime(government_budget["DateTime"], errors='coerce')
government_budget["LastUpdate"] = pd.to_datetime(government_budget["LastUpdate"], errors='coerce')

government_budget
# Out:
#        Country           Category   DateTime  Value Frequency  \
# 0   Bangladesh  Government Budget 1991-12-31  -3.30    Yearly
# 1   Bangladesh  Government Budget 1992-12-31  -2.10    Yearly
# 2   Bangladesh  Government Budget 1993-12-31  -1.30    Yearly
# 3   Bangladesh  Government Budget 1994-12-31  -3.70    Yearly
# 4   Bangladesh  Government Budget 1995-12-31  -2.20    Yearly
# 5   Bangladesh  Government Budget 1996-12-31  -3.00    Yearly
# 6   Bangladesh  Government Budget 1997-12-31  -2.00    Yearly
# 7   Bangladesh  Government Budget 1998-12-31  -2.10    Yearly
# 8   Bangladesh  Government Budget 1999-12-31  -3.20    Yearly
# 9   Bangladesh  Government Budget 2000-12-31  -4.50    Yearly
# 10  Bangladesh  Government Budget 2001-12-31  -4.10    Yearly
# 11  Bangladesh  Government Budget 2002-12-31  -3.70    Yearly
# 12  Bangladesh  Government Budget 2003-12-31  -3.70    Yearly
# 13  Bangladesh  Government Budget 2004-12-31  -3.40    Yearly
# ...

# %%
government_budget_value = pd.read_csv("../data/tradingeconomics/Government/Government_Budget_Value.csv")

government_budget_value["DateTime"] = pd.to_datetime(government_budget_value["DateTime"], errors='coerce')
government_budget_value["LastUpdate"] = pd.to_datetime(government_budget_value["LastUpdate"], errors='coerce')

government_budget_value
# Out:
#        Country                 Category   DateTime    Value Frequency  \
# 0   Bangladesh  Government Budget Value 1995-12-31   -70.05    Yearly
# 1   Bangladesh  Government Budget Value 1996-12-31   -78.32    Yearly
# 2   Bangladesh  Government Budget Value 1997-12-31   -66.97    Yearly
# 3   Bangladesh  Government Budget Value 1998-12-31   -68.39    Yearly
# 4   Bangladesh  Government Budget Value 1999-12-31  -100.12    Yearly
# 5   Bangladesh  Government Budget Value 2000-12-31  -143.90    Yearly
# 6   Bangladesh  Government Budget Value 2001-12-31  -130.57    Yearly
# 7   Bangladesh  Government Budget Value 2002-12-31  -128.64    Yearly
# 8   Bangladesh  Government Budget Value 2003-12-31  -109.55    Yearly
# 9   Bangladesh  Government Budget Value 2004-12-31  -117.84    Yearly
# 10  Bangladesh  Government Budget Value 2005-12-31  -147.03    Yearly
# 11  Bangladesh  Government Budget Value 2006-12-31  -195.15    Yearly
# ...

# %%
government_spending = pd.read_csv("../data/tradingeconomics/Government/Government_Spending.csv")

government_spending["DateTime"] = pd.to_datetime(government_spending["DateTime"], errors='coerce')
government_spending["LastUpdate"] = pd.to_datetime(government_spending["LastUpdate"], errors='coerce')

government_spending
# Out:
#       Country             Category   DateTime   Value Frequency  \
# 0  Bangladesh  Government Spending 2016-06-30  1217.5    Yearly
# 1  Bangladesh  Government Spending 2017-06-30  1305.2    Yearly
# 2  Bangladesh  Government Spending 2018-06-30  1374.1    Yearly
# 3  Bangladesh  Government Spending 2019-06-30  1558.2    Yearly
# 4  Bangladesh  Government Spending 2020-06-30  1588.6    Yearly
# 5  Bangladesh  Government Spending 2021-06-30  1697.9    Yearly
# 6  Bangladesh  Government Spending 2022-06-30  1803.9    Yearly
# 7  Bangladesh  Government Spending 2023-06-30  1957.8    Yearly
# 8  Bangladesh  Government Spending 2024-06-30  2149.2    Yearly
# 9  Bangladesh  Government Spending 2025-06-30  2218.2    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0     BANGLADESHGOVSPE 2025-11-13 04:44:00
# 1     BANGLADESHGOVSPE 2025-11-13 04:44:00
# 2     BANGLADESHGOVSPE 2025-11-13 04:44:00
# 3     BANGLADESHGOVSPE 2025-11-13 04:44:00
# ...

# %%
government_revenues = pd.read_csv("../data/tradingeconomics/Government/Government_Revenues.csv")

government_revenues["DateTime"] = pd.to_datetime(government_revenues["DateTime"], errors='coerce')
government_revenues["LastUpdate"] = pd.to_datetime(government_revenues["LastUpdate"], errors='coerce')

government_revenues
# Out:
#        Country             Category   DateTime    Value Frequency  \
# 0   Bangladesh  Government Revenues 1995-12-31   150.08    Yearly
# 1   Bangladesh  Government Revenues 1996-12-31   153.33    Yearly
# 2   Bangladesh  Government Revenues 1997-12-31   173.85    Yearly
# 3   Bangladesh  Government Revenues 1998-12-31   190.20    Yearly
# 4   Bangladesh  Government Revenues 1999-12-31   197.67    Yearly
# 5   Bangladesh  Government Revenues 2000-12-31   200.74    Yearly
# 6   Bangladesh  Government Revenues 2001-12-31   243.42    Yearly
# 7   Bangladesh  Government Revenues 2002-12-31   278.93    Yearly
# 8   Bangladesh  Government Revenues 2003-12-31   311.20    Yearly
# 9   Bangladesh  Government Revenues 2004-12-31   354.00    Yearly
# 10  Bangladesh  Government Revenues 2005-12-31   392.00    Yearly
# 11  Bangladesh  Government Revenues 2006-12-31   448.68    Yearly
# 12  Bangladesh  Government Revenues 2007-12-31   516.22    Yearly
# ...

# %%
fiscal_expenditure = pd.read_csv("../data/tradingeconomics/Government/Fiscal_Expenditure.csv")

fiscal_expenditure["DateTime"] = pd.to_datetime(fiscal_expenditure["DateTime"], errors='coerce')
fiscal_expenditure["LastUpdate"] = pd.to_datetime(fiscal_expenditure["LastUpdate"], errors='coerce')

fiscal_expenditure
# Out:
#        Country            Category   DateTime    Value Frequency  \
# 0   Bangladesh  Fiscal Expenditure 1995-12-31   220.13    Yearly
# 1   Bangladesh  Fiscal Expenditure 1996-12-31   231.65    Yearly
# 2   Bangladesh  Fiscal Expenditure 1997-12-31   240.82    Yearly
# 3   Bangladesh  Fiscal Expenditure 1998-12-31   258.59    Yearly
# 4   Bangladesh  Fiscal Expenditure 1999-12-31   297.79    Yearly
# 5   Bangladesh  Fiscal Expenditure 2000-12-31   344.64    Yearly
# 6   Bangladesh  Fiscal Expenditure 2001-12-31   373.99    Yearly
# 7   Bangladesh  Fiscal Expenditure 2002-12-31   407.57    Yearly
# 8   Bangladesh  Fiscal Expenditure 2003-12-31   420.75    Yearly
# 9   Bangladesh  Fiscal Expenditure 2004-12-31   471.84    Yearly
# 10  Bangladesh  Fiscal Expenditure 2005-12-31   539.03    Yearly
# 11  Bangladesh  Fiscal Expenditure 2006-12-31   643.83    Yearly
# 12  Bangladesh  Fiscal Expenditure 2007-12-31   668.36    Yearly
# ...

# %%
corruption_index = pd.read_csv("../data/tradingeconomics/Government/Corruption_Index.csv")

corruption_index["DateTime"] = pd.to_datetime(corruption_index["DateTime"], errors='coerce')
corruption_index["LastUpdate"] = pd.to_datetime(corruption_index["LastUpdate"], errors='coerce')

corruption_index
# Out:
#        Country          Category   DateTime  Value Frequency  \
# 0   Bangladesh  Corruption Index 1996-12-31   22.9    Yearly
# 1   Bangladesh  Corruption Index 2001-12-31    4.0    Yearly
# 2   Bangladesh  Corruption Index 2002-12-31   12.0    Yearly
# 3   Bangladesh  Corruption Index 2003-12-31   13.0    Yearly
# 4   Bangladesh  Corruption Index 2004-12-31   15.0    Yearly
# 5   Bangladesh  Corruption Index 2005-12-31   17.0    Yearly
# 6   Bangladesh  Corruption Index 2006-12-31   20.0    Yearly
# 7   Bangladesh  Corruption Index 2007-12-31   20.0    Yearly
# 8   Bangladesh  Corruption Index 2008-12-31   21.0    Yearly
# 9   Bangladesh  Corruption Index 2009-12-31   24.0    Yearly
# 10  Bangladesh  Corruption Index 2010-12-31   24.0    Yearly
# 11  Bangladesh  Corruption Index 2011-12-31   27.0    Yearly
# 12  Bangladesh  Corruption Index 2012-12-31   26.0    Yearly
# 13  Bangladesh  Corruption Index 2013-12-31   27.0    Yearly
# ...

# %%
corruption_rank = pd.read_csv("../data/tradingeconomics/Government/Corruption_Rank.csv")

corruption_rank["DateTime"] = pd.to_datetime(corruption_rank["DateTime"], errors='coerce')
corruption_rank["LastUpdate"] = pd.to_datetime(corruption_rank["LastUpdate"], errors='coerce')

corruption_rank
# Out:
#        Country         Category   DateTime  Value Frequency  \
# 0   Bangladesh  Corruption Rank 1996-12-31     51    Yearly
# 1   Bangladesh  Corruption Rank 2001-12-31     91    Yearly
# 2   Bangladesh  Corruption Rank 2002-12-31    102    Yearly
# 3   Bangladesh  Corruption Rank 2003-12-31    133    Yearly
# 4   Bangladesh  Corruption Rank 2004-12-31    145    Yearly
# 5   Bangladesh  Corruption Rank 2005-12-31    158    Yearly
# 6   Bangladesh  Corruption Rank 2006-12-31    156    Yearly
# 7   Bangladesh  Corruption Rank 2007-12-31    162    Yearly
# 8   Bangladesh  Corruption Rank 2008-12-31    147    Yearly
# 9   Bangladesh  Corruption Rank 2009-12-31    139    Yearly
# 10  Bangladesh  Corruption Rank 2010-12-31    134    Yearly
# 11  Bangladesh  Corruption Rank 2011-12-31    120    Yearly
# 12  Bangladesh  Corruption Rank 2012-12-31    144    Yearly
# 13  Bangladesh  Corruption Rank 2013-12-31    136    Yearly
# 14  Bangladesh  Corruption Rank 2014-12-31    145    Yearly
# ...

# %%
military_expenditure = pd.read_csv("../data/tradingeconomics/Government/Military_Expenditure.csv")

military_expenditure["DateTime"] = pd.to_datetime(military_expenditure["DateTime"], errors='coerce')
military_expenditure["LastUpdate"] = pd.to_datetime(military_expenditure["LastUpdate"], errors='coerce')

military_expenditure
# Out:
#        Country              Category   DateTime   Value Frequency  \
# 0   Bangladesh  Military Expenditure 1973-12-31    48.6    Yearly
# 1   Bangladesh  Military Expenditure 1974-12-31    72.3    Yearly
# 2   Bangladesh  Military Expenditure 1975-12-31    80.8    Yearly
# 3   Bangladesh  Military Expenditure 1976-12-31   105.3    Yearly
# 4   Bangladesh  Military Expenditure 1977-12-31   128.5    Yearly
# 5   Bangladesh  Military Expenditure 1978-12-31   134.9    Yearly
# 6   Bangladesh  Military Expenditure 1979-12-31   136.3    Yearly
# 7   Bangladesh  Military Expenditure 1980-12-31   167.3    Yearly
# 8   Bangladesh  Military Expenditure 1981-12-31   174.1    Yearly
# 9   Bangladesh  Military Expenditure 1982-12-31   184.7    Yearly
# 10  Bangladesh  Military Expenditure 1983-12-31   231.8    Yearly
# 11  Bangladesh  Military Expenditure 1984-12-31   244.3    Yearly
# 12  Bangladesh  Military Expenditure 1985-12-31   224.9    Yearly
# ...

# %%
corporate_tax_rate = pd.read_csv("../data/tradingeconomics/Government/Corporate_Tax_Rate.csv")

corporate_tax_rate["DateTime"] = pd.to_datetime(corporate_tax_rate["DateTime"], errors='coerce')
corporate_tax_rate["LastUpdate"] = pd.to_datetime(corporate_tax_rate["LastUpdate"], errors='coerce')

corporate_tax_rate
# Out:
#        Country            Category   DateTime  Value Frequency  \
# 0   Bangladesh  Corporate Tax Rate 1997-12-31   40.0    Yearly
# 1   Bangladesh  Corporate Tax Rate 1998-12-31   40.0    Yearly
# 2   Bangladesh  Corporate Tax Rate 1999-12-31   35.0    Yearly
# 3   Bangladesh  Corporate Tax Rate 2000-12-31   35.0    Yearly
# 4   Bangladesh  Corporate Tax Rate 2001-12-31   35.0    Yearly
# 5   Bangladesh  Corporate Tax Rate 2002-12-31   35.0    Yearly
# 6   Bangladesh  Corporate Tax Rate 2003-12-31   30.0    Yearly
# 7   Bangladesh  Corporate Tax Rate 2004-12-31   30.0    Yearly
# 8   Bangladesh  Corporate Tax Rate 2005-12-31   30.0    Yearly
# 9   Bangladesh  Corporate Tax Rate 2006-12-31   30.0    Yearly
# 10  Bangladesh  Corporate Tax Rate 2007-12-31   30.0    Yearly
# 11  Bangladesh  Corporate Tax Rate 2008-12-31   30.0    Yearly
# 12  Bangladesh  Corporate Tax Rate 2009-12-31   27.5    Yearly
# 13  Bangladesh  Corporate Tax Rate 2010-12-31   27.5    Yearly
# ...

# %%
personal_income_tax_rate = pd.read_csv("../data/tradingeconomics/Government/Personal_Income_Tax_Rate.csv")

personal_income_tax_rate["DateTime"] = pd.to_datetime(personal_income_tax_rate["DateTime"], errors='coerce')
personal_income_tax_rate["LastUpdate"] = pd.to_datetime(personal_income_tax_rate["LastUpdate"], errors='coerce')

personal_income_tax_rate
# Out:
#        Country                  Category   DateTime  Value Frequency  \
# 0   Bangladesh  Personal Income Tax Rate 2004-12-31     25    Yearly
# 1   Bangladesh  Personal Income Tax Rate 2005-12-31     25    Yearly
# 2   Bangladesh  Personal Income Tax Rate 2006-12-31     25    Yearly
# 3   Bangladesh  Personal Income Tax Rate 2007-12-31     25    Yearly
# 4   Bangladesh  Personal Income Tax Rate 2008-12-31     25    Yearly
# 5   Bangladesh  Personal Income Tax Rate 2009-12-31     25    Yearly
# 6   Bangladesh  Personal Income Tax Rate 2010-12-31     25    Yearly
# 7   Bangladesh  Personal Income Tax Rate 2011-12-31     25    Yearly
# 8   Bangladesh  Personal Income Tax Rate 2012-12-31     25    Yearly
# 9   Bangladesh  Personal Income Tax Rate 2013-12-31     25    Yearly
# 10  Bangladesh  Personal Income Tax Rate 2014-12-31     30    Yearly
# 11  Bangladesh  Personal Income Tax Rate 2015-12-31     30    Yearly
# 12  Bangladesh  Personal Income Tax Rate 2016-12-31     30    Yearly
# ...

# %%
sales_tax_rate = pd.read_csv("../data/tradingeconomics/Government/Sales_Tax_Rate.csv")

sales_tax_rate["DateTime"] = pd.to_datetime(sales_tax_rate["DateTime"], errors='coerce')
sales_tax_rate["LastUpdate"] = pd.to_datetime(sales_tax_rate["LastUpdate"], errors='coerce')

sales_tax_rate
# Out:
#        Country        Category   DateTime  Value Frequency  \
# 0   Bangladesh  Sales Tax Rate 2006-12-31     15    Yearly
# 1   Bangladesh  Sales Tax Rate 2007-12-31     15    Yearly
# 2   Bangladesh  Sales Tax Rate 2008-12-31     15    Yearly
# 3   Bangladesh  Sales Tax Rate 2009-12-31     15    Yearly
# 4   Bangladesh  Sales Tax Rate 2010-12-31     15    Yearly
# 5   Bangladesh  Sales Tax Rate 2011-12-31     15    Yearly
# 6   Bangladesh  Sales Tax Rate 2012-12-31     15    Yearly
# 7   Bangladesh  Sales Tax Rate 2013-12-31     15    Yearly
# 8   Bangladesh  Sales Tax Rate 2014-12-31     15    Yearly
# 9   Bangladesh  Sales Tax Rate 2015-12-31     15    Yearly
# 10  Bangladesh  Sales Tax Rate 2016-12-31     15    Yearly
# 11  Bangladesh  Sales Tax Rate 2017-12-31     15    Yearly
# 12  Bangladesh  Sales Tax Rate 2018-12-31     15    Yearly
# 13  Bangladesh  Sales Tax Rate 2019-12-31     15    Yearly
# 14  Bangladesh  Sales Tax Rate 2020-12-31     15    Yearly
# ...

# %% [markdown]
# <br> <br>
#
# ## Business

# %%
manufacturing_production = pd.read_csv("../data/tradingeconomics/Business/Manufacturing_Production.csv")

manufacturing_production["DateTime"] = pd.to_datetime(manufacturing_production["DateTime"], errors='coerce')
manufacturing_production["LastUpdate"] = pd.to_datetime(manufacturing_production["LastUpdate"], errors='coerce')

manufacturing_production
# Out:
#         Country                  Category   DateTime  Value Frequency  \
# 0    Bangladesh  Manufacturing Production 2013-02-28   3.00   Monthly
# 1    Bangladesh  Manufacturing Production 2013-03-31   9.20   Monthly
# 2    Bangladesh  Manufacturing Production 2013-04-30  10.90   Monthly
# 3    Bangladesh  Manufacturing Production 2013-05-31  13.60   Monthly
# 4    Bangladesh  Manufacturing Production 2013-06-30  11.40   Monthly
# ..          ...                       ...        ...    ...       ...
# 148  Bangladesh  Manufacturing Production 2025-06-30  -1.02   Monthly
# 149  Bangladesh  Manufacturing Production 2025-07-31  11.02   Monthly
# 150  Bangladesh  Manufacturing Production 2025-08-31   4.05   Monthly
# 151  Bangladesh  Manufacturing Production 2025-09-30   3.58   Monthly
# 152  Bangladesh  Manufacturing Production 2025-10-31   2.33   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0       BANGLADESHMANPRO 2017-08-28 16:09:00
# ...

# %%
mining_production = pd.read_csv("../data/tradingeconomics/Business/Mining_Production.csv")

mining_production["DateTime"] = pd.to_datetime(mining_production["DateTime"], errors='coerce')
mining_production["LastUpdate"] = pd.to_datetime(mining_production["LastUpdate"], errors='coerce')

mining_production
# Out:
#         Country           Category   DateTime  Value Frequency  \
# 0    Bangladesh  Mining Production 2014-04-30   4.10   Monthly
# 1    Bangladesh  Mining Production 2014-05-31   5.00   Monthly
# 2    Bangladesh  Mining Production 2014-06-30   0.80   Monthly
# 3    Bangladesh  Mining Production 2014-07-31  -2.00   Monthly
# 4    Bangladesh  Mining Production 2014-08-31   6.10   Monthly
# ..          ...                ...        ...    ...       ...
# 133  Bangladesh  Mining Production 2025-06-30  -4.26   Monthly
# 134  Bangladesh  Mining Production 2025-07-31  -3.18   Monthly
# 135  Bangladesh  Mining Production 2025-08-31 -14.04   Monthly
# 136  Bangladesh  Mining Production 2025-09-30 -13.48   Monthly
# 137  Bangladesh  Mining Production 2025-10-31 -14.74   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0       BANGLADESHMINPRO 2017-08-28 16:24:00
# 1       BANGLADESHMINPRO 2017-08-28 16:24:00
# 2       BANGLADESHMINPRO 2017-08-28 16:24:00
# ...

# %% [markdown]
# <br> <br>
#
# ## Consumer

# %%
consumer_spending = pd.read_csv("../data/tradingeconomics/Consumer/Consumer_Spending.csv")

consumer_spending["DateTime"] = pd.to_datetime(consumer_spending["DateTime"], errors='coerce')
consumer_spending["LastUpdate"] = pd.to_datetime(consumer_spending["LastUpdate"], errors='coerce')

consumer_spending
# Out:
#       Country           Category   DateTime    Value Frequency  \
# 0  Bangladesh  Consumer Spending 2016-06-30  13879.9    Yearly
# 1  Bangladesh  Consumer Spending 2017-06-30  14750.0    Yearly
# 2  Bangladesh  Consumer Spending 2018-06-30  16138.5    Yearly
# 3  Bangladesh  Consumer Spending 2019-06-30  16922.1    Yearly
# 4  Bangladesh  Consumer Spending 2020-06-30  17429.2    Yearly
# 5  Bangladesh  Consumer Spending 2021-06-30  18826.2    Yearly
# 6  Bangladesh  Consumer Spending 2022-06-30  20233.7    Yearly
# 7  Bangladesh  Consumer Spending 2023-06-30  20635.4    Yearly
# 8  Bangladesh  Consumer Spending 2024-06-30  21871.7    Yearly
# 9  Bangladesh  Consumer Spending 2025-06-30  22914.2    Yearly
#
#   HistoricalDataSymbol          LastUpdate
# 0     BANGLADESHCONSPE 2025-11-13 04:34:00
# 1     BANGLADESHCONSPE 2025-11-13 04:34:00
# 2     BANGLADESHCONSPE 2025-11-13 04:34:00
# 3     BANGLADESHCONSPE 2025-11-13 04:34:00
# 4     BANGLADESHCONSPE 2025-11-13 04:34:00
# ...

# %%
private_sector_credit = pd.read_csv("../data/tradingeconomics/Consumer/Private_Sector_Credit.csv")

private_sector_credit["DateTime"] = pd.to_datetime(private_sector_credit["DateTime"], errors='coerce')
private_sector_credit["LastUpdate"] = pd.to_datetime(private_sector_credit["LastUpdate"], errors='coerce')

private_sector_credit
# Out:
#         Country               Category   DateTime    Value Frequency  \
# 0    Bangladesh  Private Sector Credit 1999-06-30    498.3   Monthly
# 1    Bangladesh  Private Sector Credit 2000-06-30    549.5   Monthly
# 2    Bangladesh  Private Sector Credit 2001-06-30    638.8   Monthly
# 3    Bangladesh  Private Sector Credit 2002-06-30    730.4   Monthly
# 4    Bangladesh  Private Sector Credit 2003-06-30    824.0   Monthly
# ..          ...                    ...        ...      ...       ...
# 169  Bangladesh  Private Sector Credit 2025-06-30  17253.6   Monthly
# 170  Bangladesh  Private Sector Credit 2025-07-31  17205.4   Monthly
# 171  Bangladesh  Private Sector Credit 2025-08-31  17255.4   Monthly
# 172  Bangladesh  Private Sector Credit 2025-09-30  17345.3   Monthly
# 173  Bangladesh  Private Sector Credit 2025-10-31  17388.2   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0    BANGLADESHPRISECCRE 2025-04-18 06:04:00
# 1    BANGLADESHPRISECCRE 2025-04-18 06:04:00
# ...

# %%
consumer_credit = pd.read_csv("../data/tradingeconomics/Consumer/Consumer_Credit.csv")

consumer_credit["DateTime"] = pd.to_datetime(consumer_credit["DateTime"], errors='coerce')
consumer_credit["LastUpdate"] = pd.to_datetime(consumer_credit["LastUpdate"], errors='coerce')

consumer_credit
# Out:
#         Country         Category   DateTime     Value Frequency  \
# 0    Bangladesh  Consumer Credit 1990-01-31    220.17   Monthly
# 1    Bangladesh  Consumer Credit 1990-02-28    222.50   Monthly
# 2    Bangladesh  Consumer Credit 1990-03-30    221.43   Monthly
# 3    Bangladesh  Consumer Credit 1990-03-31    221.43   Monthly
# 4    Bangladesh  Consumer Credit 1990-04-30    221.37   Monthly
# ..          ...              ...        ...       ...       ...
# 488  Bangladesh  Consumer Credit 2025-06-30  22843.53   Monthly
# 489  Bangladesh  Consumer Credit 2025-07-31  22924.66   Monthly
# 490  Bangladesh  Consumer Credit 2025-08-31  22925.54   Monthly
# 491  Bangladesh  Consumer Credit 2025-09-30  23211.56   Monthly
# 492  Bangladesh  Consumer Credit 2025-10-31  23358.85   Monthly
#
#     HistoricalDataSymbol          LastUpdate
# 0       BANGLADESHCONCRE 2014-11-16 21:28:00
# 1       BANGLADESHCONCRE 2014-11-16 21:28:00
# 2       BANGLADESHCONCRE 2014-11-16 21:28:00
# ...
